# %% [markdown]
# FEDADAM WITH FASHIONMNIST - 1 LOCAL EPOCH WITH 100 ROUNDS

# %%
import flwr as fl
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import datasets, transforms
from torch.utils.data import DataLoader, random_split, Subset
import numpy as np
import matplotlib.pyplot as plt

# 1. Model for FashionMNIST (1 channel)
class SimpleCNN(nn.Module):
    def __init__(self):
        super().__init__()
        self.conv = nn.Sequential(
            nn.Conv2d(1, 32, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(2),
            nn.Conv2d(32, 64, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(2),
        )
        self.fc = nn.Sequential(
            nn.Flatten(),
            nn.Linear(64 * 7 * 7, 128),
            nn.ReLU(),
            nn.Linear(128, 10)  # FashionMNIST has 10 classes
        )

    def forward(self, x):
        x = self.conv(x)
        x = self.fc(x)
        return x

# 2. Device
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# 3. Load FashionMNIST
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.2860,), (0.3530,))
])
trainset = datasets.FashionMNIST(root="./data", train=True, download=True, transform=transform)
testset = datasets.FashionMNIST(root="./data", train=False, download=True, transform=transform)

# 4. Client Data Loader
def get_client_dataloader(cid, num_clients=5, batch_size=32):
    total_size = len(trainset)
    client_size = total_size // num_clients
    indices = list(range(cid * client_size, (cid + 1) * client_size))
    subset = Subset(trainset, indices)
    train_len = int(0.8 * len(subset))
    val_len = len(subset) - train_len
    train_data, val_data = random_split(subset, [train_len, val_len])
    return (
        DataLoader(train_data, batch_size=batch_size, shuffle=True),
        DataLoader(val_data, batch_size=batch_size, shuffle=False),
    )

testloader = DataLoader(testset, batch_size=32)

# 5. Flower Client
class FlowerClient(fl.client.NumPyClient):
    def __init__(self, cid):
        self.cid = int(cid)
        self.model = SimpleCNN().to(DEVICE)
        self.trainloader, self.valloader = get_client_dataloader(self.cid)

    def get_parameters(self, config):
        return [val.cpu().numpy() for val in self.model.state_dict().values()]

    def set_parameters(self, parameters):
        state_dict = self.model.state_dict()
        for k, v in zip(state_dict.keys(), parameters):
            state_dict[k] = torch.tensor(v)
        self.model.load_state_dict(state_dict)

    def fit(self, parameters, config):
        self.set_parameters(parameters)
        self.model.train()
        optimizer = optim.Adam(self.model.parameters(), lr=0.001)
        criterion = nn.CrossEntropyLoss()
        for _ in range(1):  # 1 local epoch
            for x, y in self.trainloader:
                x, y = x.to(DEVICE), y.to(DEVICE)
                optimizer.zero_grad()
                out = self.model(x)
                loss = criterion(out, y)
                loss.backward()
                optimizer.step()
        return self.get_parameters({}), len(self.trainloader.dataset), {}

    def evaluate(self, parameters, config):
        self.set_parameters(parameters)
        self.model.eval()
        criterion = nn.CrossEntropyLoss()
        correct = 0
        total = 0
        loss = 0
        with torch.no_grad():
            for x, y in self.valloader:
                x, y = x.to(DEVICE), y.to(DEVICE)
                out = self.model(x)
                loss += criterion(out, y).item()
                pred = torch.argmax(out, dim=1)
                correct += (pred == y).sum().item()
                total += y.size(0)
        return loss / len(self.valloader), len(self.valloader.dataset), {"val_accuracy": correct / total}

# 6. Client function
def client_fn(cid: str):
    return FlowerClient(int(cid)).to_client()

# 7. Evaluate function
test_losses, test_accuracies = [], []

def evaluate_fn(server_round, parameters, config):
    model = SimpleCNN().to(DEVICE)
    state_dict = model.state_dict()
    for k, v in zip(state_dict.keys(), parameters):
        state_dict[k] = torch.tensor(v)
    model.load_state_dict(state_dict)
    model.eval()
    criterion = nn.CrossEntropyLoss()
    correct, total, loss = 0, 0, 0
    with torch.no_grad():
        for x, y in testloader:
            x, y = x.to(DEVICE), y.to(DEVICE)
            out = model(x)
            loss += criterion(out, y).item()
            pred = torch.argmax(out, dim=1)
            correct += (pred == y).sum().item()
            total += y.size(0)
    acc = correct / total
    test_losses.append(loss / len(testloader))
    test_accuracies.append(acc)
    print(f"[Round {server_round}] Test Loss: {loss:.4f}, Accuracy: {acc:.4f}")
    return loss, {"test_accuracy": acc}

# 8. Start simulation
if __name__ == "__main__":
    model = SimpleCNN()
    initial_weights = [val.cpu().numpy() for val in model.state_dict().values()]
    initial_parameters = fl.common.ndarrays_to_parameters(initial_weights)

    fl.simulation.start_simulation(
        client_fn=client_fn,
        num_clients=5,
        config=fl.server.ServerConfig(num_rounds=100),
        strategy=fl.server.strategy.FedAdam(
            eta=0.001,
            eta_l=0.001,
            beta_1=0.9,
            beta_2=0.99,
            tau=1e-9,
            fraction_fit=1.0,
            fraction_evaluate=1.0,
            min_fit_clients=5,
            min_evaluate_clients=5,
            min_available_clients=5,
            evaluate_fn=evaluate_fn,
            initial_parameters=initial_parameters,
        ),
    )

    # 9. Plot results
    rounds = list(range(1, len(test_losses) + 1))
    plt.figure(figsize=(10, 5))
    plt.plot(rounds, test_losses, marker='o', label="Test Loss")
    plt.plot(rounds, test_accuracies, marker='o', label="Test Accuracy")
    plt.xlabel("Round")
    plt.ylabel("Metric")
    plt.title("FedAdam on FashionMNIST")
    plt.grid(True)
    plt.legend()
    plt.tight_layout()
    plt.savefig("fashionmnist_fedadam_plot.png")
    plt.show()

    # 10. Save results
    np.save("fashionmnist_test_losses.npy", np.array(test_losses))
    np.save("fashionmnist_test_accuracies.npy", np.array(test_accuracies))
# Out:
# 2025-08-01 16:01:34,725	INFO util.py:154 -- Outdated packages:
#   ipywidgets==7.8.1 found, needs ipywidgets>=8
# Run `pip install -U ipywidgets`, then restart the notebook server for rich notebook output.
# WARNING :   DEPRECATED FEATURE: flwr.simulation.start_simulation() is deprecated.
# 	Instead, use the `flwr run` CLI command to start a local simulation in your Flower app, as shown for example below:
#
# 		$ flwr new  # Create a new Flower app from a template
#
# 		$ flwr run  # Run the Flower app in Simulation Mode
#
# 	Using `start_simulation()` is deprecated.
#
#             This is a deprecated feature. It will be removed
#             entirely in future versions of Flower.
#
# INFO :      Starting Flower simulation, config: num_rounds=100, no round_timeout
# 2025-08-01 16:01:38,640	INFO worker.py:1771 -- Started a local Ray instance.
# INFO :      Flower VCE: Ray initialized with resources: {'CPU': 8.0, 'object_store_memory': 1703583744.0, 'memory': 3407167488.0, 'node:__internal_head__': 1.0, 'node:127.0.0.1': 1.0}
# INFO :      Optimize your simulation with Flower VCE: https://flower.ai/docs/framework/how-to-run-simulations.html
# INFO :      No `client_resources` specified. Using minimal resources for clients.
# INFO :      Flower VCE: Resources for each Virtual Client: {'num_cpus': 1, 'num_gpus': 0.0}
# INFO :      Flower VCE: Creating VirtualClientEngineActorPool with 8 actors
# INFO :      [INIT]
# INFO :      Using initial global parameters provided by strategy
# INFO :      Starting evaluation of initial global parameters
# INFO :      initial parameters (loss, other metrics): 721.3298652172089, {'test_accuracy': 0.0959}
# INFO :
# INFO :      [ROUND 1]
# INFO :      configure_fit: strategy sampled 5 clients (out of 5)
# [Round 0] Test Loss: 721.3299, Accuracy: 0.0959
# (ClientAppActor pid=92050) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context`
# (ClientAppActor pid=92050)
# (ClientAppActor pid=92050)             This is a deprecated feature. It will be removed
# (ClientAppActor pid=92050)             entirely in future versions of Flower.
# (ClientAppActor pid=92050)
# (ClientAppActor pid=92055)
# (ClientAppActor pid=92055)
# (ClientAppActor pid=92053)
# (ClientAppActor pid=92053)
# (ClientAppActor pid=92054)
# (ClientAppActor pid=92054)
# (ClientAppActor pid=92052)
# (ClientAppActor pid=92052)
# INFO :      aggregate_fit: received 5 results and 0 failures
# WARNING :   No fit_metrics_aggregation_fn provided
# INFO :      fit progress: (1, 695.4868550300598, {'test_accuracy': 0.4415}, 30.954795417143032)
# INFO :      configure_evaluate: strategy sampled 5 clients (out of 5)
# [Round 1] Test Loss: 695.4869, Accuracy: 0.4415
# (ClientAppActor pid=92053)
# (ClientAppActor pid=92053)
# (ClientAppActor pid=92053) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 5x across cluster] (Ray deduplicates logs by default. Set RAY_DEDUP_LOGS=0 to disable log deduplication, or see https://docs.ray.io/en/master/ray-observability/user-guides/configure-logging.html#log-deduplication for more options.)
# (ClientAppActor pid=92053)             This is a deprecated feature. It will be removed [repeated 5x across cluster]
# (ClientAppActor pid=92053)             entirely in future versions of Flower. [repeated 5x across cluster]
# (ClientAppActor pid=92050)
# (ClientAppActor pid=92050)
# (ClientAppActor pid=92052)
# (ClientAppActor pid=92052)
# (ClientAppActor pid=92055)
# (ClientAppActor pid=92055)
# (ClientAppActor pid=92054)
# (ClientAppActor pid=92054)
# INFO :      aggregate_evaluate: received 5 results and 0 failures
# WARNING :   No evaluate_metrics_aggregation_fn provided
# INFO :
# INFO :      [ROUND 2]
# INFO :      configure_fit: strategy sampled 5 clients (out of 5)
# (ClientAppActor pid=92055)
# (ClientAppActor pid=92055)
# (ClientAppActor pid=92054)
# (ClientAppActor pid=92054)
# (ClientAppActor pid=92050)
# (ClientAppActor pid=92050)
# (ClientAppActor pid=92052)
# (ClientAppActor pid=92052)
# (ClientAppActor pid=92053)
# (ClientAppActor pid=92053)
# INFO :      aggregate_fit: received 5 results and 0 failures
# INFO :      fit progress: (2, 664.7318897247314, {'test_accuracy': 0.5811}, 43.52712425007485)
# INFO :      configure_evaluate: strategy sampled 5 clients (out of 5)
# [Round 2] Test Loss: 664.7319, Accuracy: 0.5811
# (ClientAppActor pid=92052)
# (ClientAppActor pid=92052)
# (ClientAppActor pid=92052) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 10x across cluster]
# (ClientAppActor pid=92052)             This is a deprecated feature. It will be removed [repeated 10x across cluster]
# (ClientAppActor pid=92052)             entirely in future versions of Flower. [repeated 10x across cluster]
# (ClientAppActor pid=92053)
# (ClientAppActor pid=92053)
# (ClientAppActor pid=92054)
# (ClientAppActor pid=92054)
# (ClientAppActor pid=92050)
# (ClientAppActor pid=92050)
# (ClientAppActor pid=92055)
# (ClientAppActor pid=92055)
# INFO :      aggregate_evaluate: received 5 results and 0 failures
# INFO :
# INFO :      [ROUND 3]
# INFO :      configure_fit: strategy sampled 5 clients (out of 5)
# (ClientAppActor pid=92055)
# (ClientAppActor pid=92055)
# (ClientAppActor pid=92053)
# (ClientAppActor pid=92053)
# (ClientAppActor pid=92050)
# (ClientAppActor pid=92050)
# (ClientAppActor pid=92054)
# (ClientAppActor pid=92054)
# (ClientAppActor pid=92052)
# (ClientAppActor pid=92052)
# INFO :      aggregate_fit: received 5 results and 0 failures
# INFO :      fit progress: (3, 626.5560765266418, {'test_accuracy': 0.6853}, 55.80849329195917)
# INFO :      configure_evaluate: strategy sampled 5 clients (out of 5)
# [Round 3] Test Loss: 626.5561, Accuracy: 0.6853
# (ClientAppActor pid=92052)
# (ClientAppActor pid=92052)
# (ClientAppActor pid=92052) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 10x across cluster]
# (ClientAppActor pid=92052)             This is a deprecated feature. It will be removed [repeated 10x across cluster]
# (ClientAppActor pid=92052)             entirely in future versions of Flower. [repeated 10x across cluster]
# (ClientAppActor pid=92053)
# (ClientAppActor pid=92053)
# (ClientAppActor pid=92054)
# (ClientAppActor pid=92054)
# (ClientAppActor pid=92055)
# (ClientAppActor pid=92055)
# (ClientAppActor pid=92050)
# (ClientAppActor pid=92050)
# INFO :      aggregate_evaluate: received 5 results and 0 failures
# INFO :
# INFO :      [ROUND 4]
# INFO :      configure_fit: strategy sampled 5 clients (out of 5)
# (ClientAppActor pid=92050)
# (ClientAppActor pid=92050)
# (ClientAppActor pid=92055)
# (ClientAppActor pid=92055)
# (ClientAppActor pid=92053)
# (ClientAppActor pid=92053)
# (ClientAppActor pid=92054)
# (ClientAppActor pid=92054)
# (ClientAppActor pid=92052)
# (ClientAppActor pid=92052)
# INFO :      aggregate_fit: received 5 results and 0 failures
# INFO :      fit progress: (4, 584.2341763973236, {'test_accuracy': 0.7221}, 68.52637458313257)
# INFO :      configure_evaluate: strategy sampled 5 clients (out of 5)
# [Round 4] Test Loss: 584.2342, Accuracy: 0.7221
# (ClientAppActor pid=92054)
# (ClientAppActor pid=92054)
# (ClientAppActor pid=92054) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 10x across cluster]
# (ClientAppActor pid=92054)             This is a deprecated feature. It will be removed [repeated 10x across cluster]
# (ClientAppActor pid=92054)             entirely in future versions of Flower. [repeated 10x across cluster]
# (ClientAppActor pid=92053)
# (ClientAppActor pid=92053)
# (ClientAppActor pid=92052)
# (ClientAppActor pid=92052)
# (ClientAppActor pid=92055)
# (ClientAppActor pid=92055)
# (ClientAppActor pid=92050)
# (ClientAppActor pid=92050)
# INFO :      aggregate_evaluate: received 5 results and 0 failures
# INFO :
# INFO :      [ROUND 5]
# INFO :      configure_fit: strategy sampled 5 clients (out of 5)
# (ClientAppActor pid=92055)
# (ClientAppActor pid=92055)
# (ClientAppActor pid=92050)
# (ClientAppActor pid=92050)
# (ClientAppActor pid=92053)
# (ClientAppActor pid=92053)
# (ClientAppActor pid=92054)
# (ClientAppActor pid=92054)
# (ClientAppActor pid=92052)
# (ClientAppActor pid=92052)
# INFO :      aggregate_fit: received 5 results and 0 failures
# INFO :      fit progress: (5, 539.4354516267776, {'test_accuracy': 0.7429}, 81.18819150002673)
# INFO :      configure_evaluate: strategy sampled 5 clients (out of 5)
# [Round 5] Test Loss: 539.4355, Accuracy: 0.7429
# (ClientAppActor pid=92052)
# (ClientAppActor pid=92052)
# (ClientAppActor pid=92052) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 10x across cluster]
# (ClientAppActor pid=92052)             This is a deprecated feature. It will be removed [repeated 10x across cluster]
# (ClientAppActor pid=92052)             entirely in future versions of Flower. [repeated 10x across cluster]
# (ClientAppActor pid=92053)
# (ClientAppActor pid=92053)
# (ClientAppActor pid=92054)
# (ClientAppActor pid=92054)
# (ClientAppActor pid=92050)
# (ClientAppActor pid=92050)
# (ClientAppActor pid=92055)
# (ClientAppActor pid=92055)
# INFO :      aggregate_evaluate: received 5 results and 0 failures
# INFO :
# INFO :      [ROUND 6]
# INFO :      configure_fit: strategy sampled 5 clients (out of 5)
# (ClientAppActor pid=92055)
# (ClientAppActor pid=92055)
# (ClientAppActor pid=92050)
# (ClientAppActor pid=92050)
# (ClientAppActor pid=92053)
# (ClientAppActor pid=92053)
# (ClientAppActor pid=92054)
# (ClientAppActor pid=92054)
# (ClientAppActor pid=92052)
# (ClientAppActor pid=92052)
# INFO :      aggregate_fit: received 5 results and 0 failures
# INFO :      fit progress: (6, 493.76912438869476, {'test_accuracy': 0.7576}, 92.6678330830764)
# INFO :      configure_evaluate: strategy sampled 5 clients (out of 5)
# [Round 6] Test Loss: 493.7691, Accuracy: 0.7576
# (ClientAppActor pid=92052)
# (ClientAppActor pid=92052)
# (ClientAppActor pid=92052) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 10x across cluster]
# (ClientAppActor pid=92052)             This is a deprecated feature. It will be removed [repeated 10x across cluster]
# (ClientAppActor pid=92052)             entirely in future versions of Flower. [repeated 10x across cluster]
# (ClientAppActor pid=92053)
# (ClientAppActor pid=92053)
# (ClientAppActor pid=92054)
# (ClientAppActor pid=92054)
# (ClientAppActor pid=92055)
# (ClientAppActor pid=92055)
# (ClientAppActor pid=92050)
# (ClientAppActor pid=92050)
# INFO :      aggregate_evaluate: received 5 results and 0 failures
# INFO :
# INFO :      [ROUND 7]
# INFO :      configure_fit: strategy sampled 5 clients (out of 5)
# (ClientAppActor pid=92055)
# (ClientAppActor pid=92055)
# (ClientAppActor pid=92053)
# (ClientAppActor pid=92053)
# (ClientAppActor pid=92050)
# (ClientAppActor pid=92050)
# (ClientAppActor pid=92054)
# (ClientAppActor pid=92054)
# (ClientAppActor pid=92052)
# (ClientAppActor pid=92052)
# INFO :      aggregate_fit: received 5 results and 0 failures
# INFO :      fit progress: (7, 448.96407306194305, {'test_accuracy': 0.7707}, 104.2012901250273)
# INFO :      configure_evaluate: strategy sampled 5 clients (out of 5)
# [Round 7] Test Loss: 448.9641, Accuracy: 0.7707
# (ClientAppActor pid=92052)
# (ClientAppActor pid=92052)
# (ClientAppActor pid=92052) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 10x across cluster]
# (ClientAppActor pid=92052)             This is a deprecated feature. It will be removed [repeated 10x across cluster]
# (ClientAppActor pid=92052)             entirely in future versions of Flower. [repeated 10x across cluster]
# (ClientAppActor pid=92054)
# (ClientAppActor pid=92054)
# (ClientAppActor pid=92053)
# (ClientAppActor pid=92053)
# (ClientAppActor pid=92050)
# (ClientAppActor pid=92050)
# (ClientAppActor pid=92055)
# (ClientAppActor pid=92055)
# INFO :      aggregate_evaluate: received 5 results and 0 failures
# INFO :
# INFO :      [ROUND 8]
# INFO :      configure_fit: strategy sampled 5 clients (out of 5)
# (ClientAppActor pid=92055)
# (ClientAppActor pid=92055)
# (ClientAppActor pid=92053)
# (ClientAppActor pid=92053)
# (ClientAppActor pid=92050)
# (ClientAppActor pid=92050)
# (ClientAppActor pid=92054)
# (ClientAppActor pid=92054)
# (ClientAppActor pid=92052)
# (ClientAppActor pid=92052)
# INFO :      aggregate_fit: received 5 results and 0 failures
# INFO :      fit progress: (8, 406.66551315784454, {'test_accuracy': 0.7819}, 119.39638058305718)
# INFO :      configure_evaluate: strategy sampled 5 clients (out of 5)
# [Round 8] Test Loss: 406.6655, Accuracy: 0.7819
# (ClientAppActor pid=92052)
# (ClientAppActor pid=92052)
# (ClientAppActor pid=92052) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 10x across cluster]
# (ClientAppActor pid=92052)             This is a deprecated feature. It will be removed [repeated 10x across cluster]
# (ClientAppActor pid=92052)             entirely in future versions of Flower. [repeated 10x across cluster]
# (ClientAppActor pid=92054)
# (ClientAppActor pid=92054)
# (ClientAppActor pid=92055)
# (ClientAppActor pid=92055)
# (ClientAppActor pid=92050)
# (ClientAppActor pid=92050)
# (ClientAppActor pid=92053)
# (ClientAppActor pid=92053)
# INFO :      aggregate_evaluate: received 5 results and 0 failures
# INFO :
# INFO :      [ROUND 9]
# INFO :      configure_fit: strategy sampled 5 clients (out of 5)
# (ClientAppActor pid=92055)
# (ClientAppActor pid=92055)
# (ClientAppActor pid=92053)
# (ClientAppActor pid=92053)
# (ClientAppActor pid=92050)
# (ClientAppActor pid=92050)
# (ClientAppActor pid=92052)
# (ClientAppActor pid=92052)
# (ClientAppActor pid=92054)
# (ClientAppActor pid=92054)
# INFO :      aggregate_fit: received 5 results and 0 failures
# INFO :      fit progress: (9, 367.3707062602043, {'test_accuracy': 0.7909}, 131.28551891702227)
# INFO :      configure_evaluate: strategy sampled 5 clients (out of 5)
# [Round 9] Test Loss: 367.3707, Accuracy: 0.7909
# (ClientAppActor pid=92054)
# (ClientAppActor pid=92054)
# (ClientAppActor pid=92054) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 10x across cluster]
# (ClientAppActor pid=92054)             This is a deprecated feature. It will be removed [repeated 10x across cluster]
# (ClientAppActor pid=92054)             entirely in future versions of Flower. [repeated 10x across cluster]
# (ClientAppActor pid=92052)
# (ClientAppActor pid=92052)
# (ClientAppActor pid=92050)
# (ClientAppActor pid=92050)
# (ClientAppActor pid=92055)
# (ClientAppActor pid=92055)
# (ClientAppActor pid=92053)
# (ClientAppActor pid=92053)
# INFO :      aggregate_evaluate: received 5 results and 0 failures
# INFO :
# INFO :      [ROUND 10]
# INFO :      configure_fit: strategy sampled 5 clients (out of 5)
# (ClientAppActor pid=92055)
# (ClientAppActor pid=92055)
# (ClientAppActor pid=92053)
# (ClientAppActor pid=92053)
# (ClientAppActor pid=92050)
# (ClientAppActor pid=92050)
# (ClientAppActor pid=92052)
# (ClientAppActor pid=92052)
# (ClientAppActor pid=92054)
# (ClientAppActor pid=92054)
# INFO :      aggregate_fit: received 5 results and 0 failures
# INFO :      fit progress: (10, 331.55750769376755, {'test_accuracy': 0.7991}, 143.17755112494342)
# INFO :      configure_evaluate: strategy sampled 5 clients (out of 5)
# [Round 10] Test Loss: 331.5575, Accuracy: 0.7991
# (ClientAppActor pid=92054)
# (ClientAppActor pid=92054)
# (ClientAppActor pid=92054) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 10x across cluster]
# (ClientAppActor pid=92054)             This is a deprecated feature. It will be removed [repeated 10x across cluster]
# (ClientAppActor pid=92054)             entirely in future versions of Flower. [repeated 10x across cluster]
# (ClientAppActor pid=92052)
# (ClientAppActor pid=92052)
# (ClientAppActor pid=92055)
# (ClientAppActor pid=92055)
# (ClientAppActor pid=92050)
# (ClientAppActor pid=92050)
# (ClientAppActor pid=92053)
# (ClientAppActor pid=92053)
# INFO :      aggregate_evaluate: received 5 results and 0 failures
# INFO :
# INFO :      [ROUND 11]
# INFO :      configure_fit: strategy sampled 5 clients (out of 5)
# (ClientAppActor pid=92055)
# (ClientAppActor pid=92055)
# (ClientAppActor pid=92053)
# (ClientAppActor pid=92053)
# (ClientAppActor pid=92050)
# (ClientAppActor pid=92050)
# (ClientAppActor pid=92054)
# (ClientAppActor pid=92054)
# (ClientAppActor pid=92052)
# (ClientAppActor pid=92052)
# INFO :      aggregate_fit: received 5 results and 0 failures
# INFO :      fit progress: (11, 299.75428891181946, {'test_accuracy': 0.8073}, 154.60382149997167)
# INFO :      configure_evaluate: strategy sampled 5 clients (out of 5)
# [Round 11] Test Loss: 299.7543, Accuracy: 0.8073
# (ClientAppActor pid=92055)
# (ClientAppActor pid=92055)
# (ClientAppActor pid=92055) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 10x across cluster]
# (ClientAppActor pid=92055)             This is a deprecated feature. It will be removed [repeated 10x across cluster]
# (ClientAppActor pid=92055)             entirely in future versions of Flower. [repeated 10x across cluster]
# (ClientAppActor pid=92050)
# (ClientAppActor pid=92050)
# (ClientAppActor pid=92052)
# (ClientAppActor pid=92052)
# (ClientAppActor pid=92053)
# (ClientAppActor pid=92053)
# (ClientAppActor pid=92054)
# (ClientAppActor pid=92054)
# INFO :      aggregate_evaluate: received 5 results and 0 failures
# INFO :
# INFO :      [ROUND 12]
# INFO :      configure_fit: strategy sampled 5 clients (out of 5)
# (ClientAppActor pid=92053)
# (ClientAppActor pid=92053)
# (ClientAppActor pid=92054)
# (ClientAppActor pid=92054)
# (ClientAppActor pid=92050)
# (ClientAppActor pid=92050)
# (ClientAppActor pid=92052)
# (ClientAppActor pid=92052)
# (ClientAppActor pid=92055)
# (ClientAppActor pid=92055)
# INFO :      aggregate_fit: received 5 results and 0 failures
# INFO :      fit progress: (12, 271.8131530880928, {'test_accuracy': 0.8164}, 165.93748800014146)
# INFO :      configure_evaluate: strategy sampled 5 clients (out of 5)
# [Round 12] Test Loss: 271.8132, Accuracy: 0.8164
# (ClientAppActor pid=92055)
# (ClientAppActor pid=92055)
# (ClientAppActor pid=92055) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 10x across cluster]
# (ClientAppActor pid=92055)             This is a deprecated feature. It will be removed [repeated 10x across cluster]
# (ClientAppActor pid=92055)             entirely in future versions of Flower. [repeated 10x across cluster]
# (ClientAppActor pid=92053)
# (ClientAppActor pid=92053)
# (ClientAppActor pid=92052)
# (ClientAppActor pid=92052)
# (ClientAppActor pid=92050)
# (ClientAppActor pid=92050)
# (ClientAppActor pid=92054)
# (ClientAppActor pid=92054)
# INFO :      aggregate_evaluate: received 5 results and 0 failures
# INFO :
# INFO :      [ROUND 13]
# INFO :      configure_fit: strategy sampled 5 clients (out of 5)
# (ClientAppActor pid=92054)
# (ClientAppActor pid=92054)
# (ClientAppActor pid=92055)
# (ClientAppActor pid=92055)
# (ClientAppActor pid=92053)
# (ClientAppActor pid=92053)
# (ClientAppActor pid=92050)
# (ClientAppActor pid=92050)
# (ClientAppActor pid=92052)
# (ClientAppActor pid=92052)
# INFO :      aggregate_fit: received 5 results and 0 failures
# INFO :      fit progress: (13, 247.7649342417717, {'test_accuracy': 0.8214}, 177.36854750011116)
# INFO :      configure_evaluate: strategy sampled 5 clients (out of 5)
# [Round 13] Test Loss: 247.7649, Accuracy: 0.8214
# (ClientAppActor pid=92055)
# (ClientAppActor pid=92055)
# (ClientAppActor pid=92055) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 10x across cluster]
# (ClientAppActor pid=92055)             This is a deprecated feature. It will be removed [repeated 10x across cluster]
# (ClientAppActor pid=92055)             entirely in future versions of Flower. [repeated 10x across cluster]
# (ClientAppActor pid=92053)
# (ClientAppActor pid=92053)
# (ClientAppActor pid=92054)
# (ClientAppActor pid=92054)
# (ClientAppActor pid=92052)
# (ClientAppActor pid=92052)
# (ClientAppActor pid=92050)
# (ClientAppActor pid=92050)
# INFO :      aggregate_evaluate: received 5 results and 0 failures
# INFO :
# INFO :      [ROUND 14]
# INFO :      configure_fit: strategy sampled 5 clients (out of 5)
# (ClientAppActor pid=92053)
# (ClientAppActor pid=92053)
# (ClientAppActor pid=92050)
# (ClientAppActor pid=92050)
# (ClientAppActor pid=92054)
# (ClientAppActor pid=92054)
# (ClientAppActor pid=92055)
# (ClientAppActor pid=92055)
# (ClientAppActor pid=92052)
# (ClientAppActor pid=92052)
# INFO :      aggregate_fit: received 5 results and 0 failures
# INFO :      fit progress: (14, 227.00621184706688, {'test_accuracy': 0.8266}, 188.86553275003098)
# INFO :      configure_evaluate: strategy sampled 5 clients (out of 5)
# [Round 14] Test Loss: 227.0062, Accuracy: 0.8266
# (ClientAppActor pid=92054)
# (ClientAppActor pid=92054)
# (ClientAppActor pid=92054) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 10x across cluster]
# (ClientAppActor pid=92054)             This is a deprecated feature. It will be removed [repeated 10x across cluster]
# (ClientAppActor pid=92054)             entirely in future versions of Flower. [repeated 10x across cluster]
# (ClientAppActor pid=92055)
# (ClientAppActor pid=92055)
# (ClientAppActor pid=92052)
# (ClientAppActor pid=92052)
# (ClientAppActor pid=92050)
# (ClientAppActor pid=92050)
# (ClientAppActor pid=92053)
# (ClientAppActor pid=92053)
# INFO :      aggregate_evaluate: received 5 results and 0 failures
# INFO :
# INFO :      [ROUND 15]
# INFO :      configure_fit: strategy sampled 5 clients (out of 5)
# (ClientAppActor pid=92053)
# (ClientAppActor pid=92053)
# (ClientAppActor pid=92050)
# (ClientAppActor pid=92050)
# (ClientAppActor pid=92052)
# (ClientAppActor pid=92052)
# (ClientAppActor pid=92055)
# (ClientAppActor pid=92055)
# (ClientAppActor pid=92054)
# (ClientAppActor pid=92054)
# INFO :      aggregate_fit: received 5 results and 0 failures
# INFO :      fit progress: (15, 209.25355473160744, {'test_accuracy': 0.8309}, 200.58004304207861)
# INFO :      configure_evaluate: strategy sampled 5 clients (out of 5)
# [Round
# INFO :      		round 70: 82.59203608706594
# INFO :      		round 71: 82.23473174497485
# INFO :      		round 72: 81.89749864861369
# INFO :      		round 73: 81.55348582938313
# INFO :      		round 74: 81.23099241405725
# INFO :      		round 75: 80.88923277705908
# INFO :      		round 76: 80.53430546447635
# INFO :      		round 77: 80.19168718159199
# INFO :      		round 78: 79.87174539268017
# INFO :      		round 79: 79.54295233264565
# INFO :      		round 80: 79.22462661191821
# INFO :      		round 81: 78.91569554805756
# INFO :      		round 82: 78.61179957911372
# INFO :      		round 83: 78.3052663654089
# INFO :      		round 84: 78.01928097009659
# INFO :      		round 85: 77.72687396407127
# INFO :      		round 86: 77.45215776190162
# INFO :      		round 87: 77.20412718877196
# INFO :      		round 88: 76.95912386104465
# INFO :      		round 89: 76.74676890298724
# INFO :      		round 90: 76.5570422410965
# INFO :      		round 91: 76.35140493884683
# INFO :      		round 92: 76.15733329951763
# INFO :      		round 93: 75.95788737758994
# INFO :      		round 94: 75.76021826267242
# INFO :      		round 95: 75.55112506449223
# INFO :      		round 96: 75.34981354698539
# INFO :      		round 97: 75.16152015328407
# INFO :      		round 98: 74.95418257638812
# INFO :      		round 99: 74.76254787296057
# INFO :      		round 100: 74.55543741956353
# INFO :      	History (metrics, centralized):
# INFO :      	{'test_accuracy': [(0, 0.0959),
# INFO :      	                   (1, 0.4415),
# INFO :      	                   (2, 0.5811),
# INFO :      	                   (3, 0.6853),
# INFO :      	                   (4, 0.7221),
# INFO :      	                   (5, 0.7429),
# INFO :      	                   (6, 0.7576),
# INFO :      	                   (7, 0.7707),
# INFO :      	                   (8, 0.7819),
# INFO :      	                   (9, 0.7909),
# INFO :      	                   (10, 0.7991),
# INFO :      	                   (11, 0.8073),
# INFO :      	                   (12, 0.8164),
# INFO :      	                   (13, 0.8214),
# INFO :      	                   (14, 0.8266),
# INFO :      	                   (15, 0.8309),
# INFO :      	                   (16, 0.8374),
# INFO :      	                   (17, 0.8418),
# INFO :      	                   (18, 0.8452),
# INFO :      	                   (19, 0.8491),
# INFO :      	                   (20, 0.8528),
# INFO :      	                   (21, 0.8545),
# INFO :      	                   (22, 0.8578),
# INFO :      	                   (23, 0.8605),
# INFO :      	                   (24, 0.8625),
# INFO :      	                   (25, 0.8646),
# INFO :      	                   (26, 0.8668),
# INFO :      	                   (27, 0.8687),
# INFO :      	                   (28, 0.8711),
# INFO :      	                   (29, 0.8721),
# INFO :      	                   (30, 0.8733),
# INFO :      	                   (31, 0.8753),
# INFO :      	                   (32, 0.8756),
# INFO :      	                   (33, 0.8769),
# INFO :      	                   (34, 0.8777),
# INFO :      	                   (35, 0.8799),
# INFO :      	                   (36, 0.8815),
# INFO :      	                   (37, 0.8828),
# INFO :      	                   (38, 0.883),
# INFO :      	                   (39, 0.8841),
# INFO :      	                   (40, 0.8848),
# INFO :      	                   (41, 0.8852),
# INFO :      	                   (42, 0.8859),
# INFO :      	                   (43, 0.8866),
# INFO :      	                   (44, 0.8874),
# INFO :      	                   (45, 0.8887),
# INFO :      	                   (46, 0.89),
# INFO :      	                   (47, 0.8913),
# INFO :      	                   (48, 0.8917),
# INFO :      	                   (49, 0.8931),
# INFO :      	                   (50, 0.8935),
# INFO :      	                   (51, 0.8941),
# INFO :      	                   (52, 0.895),
# INFO :      	                   (53, 0.8958),
# INFO :      	                   (54, 0.8965),
# INFO :      	                   (55, 0.8969),
# INFO :      	                   (56, 0.8966),
# INFO :      	                   (57, 0.8965),
# INFO :      	                   (58, 0.8972),
# INFO :      	                   (59, 0.8978),
# INFO :      	                   (60, 0.8983),
# INFO :      	                   (61, 0.8983),
# INFO :      	                   (62, 0.899),
# INFO :      	                   (63, 0.8996),
# INFO :      	                   (64, 0.9002),
# INFO :      	                   (65, 0.901),
# INFO :      	                   (66, 0.9021),
# INFO :      	                   (67, 0.9027),
# INFO :      	                   (68, 0.9025),
# INFO :      	                   (69, 0.9031),
# INFO :      	                   (70, 0.904),
# INFO :      	                   (71, 0.9047),
# INFO :      	                   (72, 0.9051),
# INFO :      	                   (73, 0.9049),
# INFO :      	                   (74, 0.9054),
# INFO :      	                   (75, 0.9058),
# INFO :      	                   (76, 0.9062),
# INFO :      	                   (77, 0.907),
# INFO :      	                   (78, 0.9074),
# INFO :      	                   (79, 0.908),
# INFO :      	                   (80, 0.9084),
# INFO :      	                   (81, 0.9089),
# INFO :      	                   (82, 0.9089),
# INFO :      	                   (83, 0.9091),
# INFO :      	                   (84, 0.9096),
# INFO :      	                   (85, 0.9099),
# INFO :      	                   (86, 0.91),
# INFO :      	                   (87, 0.9107),
# INFO :      	                   (88, 0.9114),
# INFO :      	                   (89, 0.9122),
# INFO :      	                   (90, 0.9126),
# INFO :      	                   (91, 0.9128),
# INFO :      	                   (92, 0.9133),
# INFO :      	                   (93, 0.9134),
# INFO :      	                   (94, 0.9139),
# INFO :      	                   (95, 0.9141),
# INFO :      	                   (96, 0.9141),
# INFO :      	                   (97, 0.9148),
# INFO :      	                   (98, 0.9146),
# INFO :      	                   (99, 0.9155),
# INFO :      	                   (100, 0.9159)]}
# INFO :

# %% [markdown]
# FEDADAGRAD WITH FASHIONMNIST- 1 LOCAL EPOCH WITH 100 ROUNDS

# %%
import flwr as fl
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import matplotlib.pyplot as plt
from torch.utils.data import DataLoader, random_split, Subset
from torchvision.datasets import FashionMNIST
import torchvision.transforms as transforms

# 1. Device and transform
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.5,), (0.5,))
])

# 2. Load dataset
train_dataset = FashionMNIST(root="./data", train=True, download=True, transform=transform)
test_dataset = FashionMNIST(root="./data", train=False, download=True, transform=transform)
NUM_CLASSES = 10

# 3. Model
class SimpleCNN(nn.Module):
    def __init__(self):
        super().__init__()
        self.network = nn.Sequential(
            nn.Conv2d(1, 32, kernel_size=3, padding=1),  # 1-channel input
            nn.ReLU(),
            nn.MaxPool2d(2),
            nn.Conv2d(32, 64, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(2),
            nn.Flatten(),
            nn.Linear(64 * 7 * 7, 128),
            nn.ReLU(),
            nn.Linear(128, NUM_CLASSES)
        )

    def forward(self, x):
        return self.network(x)

# 4. Partition data for clients
def get_client_dataloader(cid, num_clients=5, batch_size=32):
    total_size = len(train_dataset)
    client_size = total_size // num_clients
    indices = list(range(cid * client_size, (cid + 1) * client_size))
    subset = Subset(train_dataset, indices)
    train_len = int(0.8 * len(subset))
    val_len = len(subset) - train_len
    train_data, val_data = random_split(subset, [train_len, val_len])
    return (
        DataLoader(train_data, batch_size=batch_size, shuffle=True),
        DataLoader(val_data, batch_size=batch_size, shuffle=False),
    )

testloader = DataLoader(test_dataset, batch_size=32)

# 5. Flower client
class FlowerClient(fl.client.NumPyClient):
    def __init__(self, cid):
        self.cid = int(cid)
        self.model = SimpleCNN().to(DEVICE)
        self.trainloader, self.valloader = get_client_dataloader(self.cid)

    def get_parameters(self, config):
        return [val.cpu().numpy() for val in self.model.state_dict().values()]

    def set_parameters(self, parameters):
        state_dict = self.model.state_dict()
        for k, v in zip(state_dict.keys(), parameters):
            state_dict[k] = torch.tensor(v)
        self.model.load_state_dict(state_dict)

    def fit(self, parameters, config):
        self.set_parameters(parameters)
        self.model.train()
        optimizer = optim.Adagrad(self.model.parameters(), lr=0.01)
        criterion = nn.CrossEntropyLoss()
        for _ in range(1):  # One local epoch
            for x, y in self.trainloader:
                x, y = x.to(DEVICE), y.to(DEVICE)
                optimizer.zero_grad()
                out = self.model(x)
                loss = criterion(out, y)
                loss.backward()
                optimizer.step()
        return self.get_parameters({}), len(self.trainloader.dataset), {}

    def evaluate(self, parameters, config):
        self.set_parameters(parameters)
        self.model.eval()
        criterion = nn.CrossEntropyLoss()
        correct, total, loss = 0, 0, 0
        with torch.no_grad():
            for x, y in self.valloader:
                x, y = x.to(DEVICE), y.to(DEVICE)
                out = self.model(x)
                loss += criterion(out, y).item()
                pred = torch.argmax(out, dim=1)
                correct += (pred == y).sum().item()
                total += y.size(0)
        return loss / len(self.valloader), len(self.valloader.dataset), {"val_accuracy": correct / total}

# 6. Client function
def client_fn(cid: str):
    return FlowerClient(int(cid)).to_client()

# 7. Evaluation on test set
test_losses, test_accuracies = [], []

def evaluate_fn(server_round, parameters, config):
    model = SimpleCNN().to(DEVICE)
    state_dict = model.state_dict()
    for k, v in zip(state_dict.keys(), parameters):
        state_dict[k] = torch.tensor(v)
    model.load_state_dict(state_dict)
    model.eval()
    criterion = nn.CrossEntropyLoss()
    correct, total, loss = 0, 0, 0
    with torch.no_grad():
        for x, y in testloader:
            x, y = x.to(DEVICE), y.to(DEVICE)
            out = model(x)
            loss += criterion(out, y).item()
            pred = torch.argmax(out, dim=1)
            correct += (pred == y).sum().item()
            total += y.size(0)
    acc = correct / total
    test_losses.append(loss / len(testloader))
    test_accuracies.append(acc)
    print(f"[Round {server_round}] Test Loss: {loss:.4f}, Accuracy: {acc:.4f}")
    return loss, {"test_accuracy": acc}

# 8. Start federated simulation
if __name__ == "__main__":
    model = SimpleCNN()
    initial_weights = [val.cpu().numpy() for val in model.state_dict().values()]
    initial_parameters = fl.common.ndarrays_to_parameters(initial_weights)

    fl.simulation.start_simulation(
        client_fn=client_fn,
        num_clients=5,
        config=fl.server.ServerConfig(num_rounds=100),
        strategy=fl.server.strategy.FedAdagrad(
            eta=0.01,
            eta_l=0.01,
            tau=1e-9,
            fraction_fit=1.0,
            fraction_evaluate=1.0,
            min_fit_clients=5,
            min_evaluate_clients=5,
            min_available_clients=5,
            evaluate_fn=evaluate_fn,
            initial_parameters=initial_parameters,
        ),
    )

    # 9. Save and plot
    np.save("fashionmnist_fedadagrad_test_losses.npy", np.array(test_losses))
    np.save("fashionmnist_fedadagrad_test_accuracies.npy", np.array(test_accuracies))

    plt.figure(figsize=(10, 5))
    plt.plot(test_losses, marker='o', label="Test Loss")
    plt.plot(test_accuracies, marker='o', label="Test Accuracy")
    plt.xlabel("Round")
    plt.ylabel("Metric")
    plt.title("FedAdagrad on FashionMNIST")
    plt.legend()
    plt.grid(True)
    plt.tight_layout()
    plt.savefig("fashionmnist_fedadagrad_plot.png")
    plt.show()
# Out:
# WARNING :   DEPRECATED FEATURE: flwr.simulation.start_simulation() is deprecated.
# 	Instead, use the `flwr run` CLI command to start a local simulation in your Flower app, as shown for example below:
#
# 		$ flwr new  # Create a new Flower app from a template
#
# 		$ flwr run  # Run the Flower app in Simulation Mode
#
# 	Using `start_simulation()` is deprecated.
#
#             This is a deprecated feature. It will be removed
#             entirely in future versions of Flower.
#
# INFO :      Starting Flower simulation, config: num_rounds=100, no round_timeout
# 2025-08-01 16:59:41,684	INFO worker.py:1771 -- Started a local Ray instance.
# INFO :      Flower VCE: Ray initialized with resources: {'node:__internal_head__': 1.0, 'object_store_memory': 1470834278.0, 'node:127.0.0.1': 1.0, 'memory': 2941668558.0, 'CPU': 8.0}
# INFO :      Optimize your simulation with Flower VCE: https://flower.ai/docs/framework/how-to-run-simulations.html
# INFO :      No `client_resources` specified. Using minimal resources for clients.
# INFO :      Flower VCE: Resources for each Virtual Client: {'num_cpus': 1, 'num_gpus': 0.0}
# INFO :      Flower VCE: Creating VirtualClientEngineActorPool with 8 actors
# INFO :      [INIT]
# INFO :      Using initial global parameters provided by strategy
# INFO :      Starting evaluation of initial global parameters
# INFO :      initial parameters (loss, other metrics): 720.5170645713806, {'test_accuracy': 0.1075}
# INFO :
# INFO :      [ROUND 1]
# INFO :      configure_fit: strategy sampled 5 clients (out of 5)
# [Round 0] Test Loss: 720.5171, Accuracy: 0.1075
# (ClientAppActor pid=93398) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context`
# (ClientAppActor pid=93398)
# (ClientAppActor pid=93398)             This is a deprecated feature. It will be removed
# (ClientAppActor pid=93398)             entirely in future versions of Flower.
# (ClientAppActor pid=93398)
# (ClientAppActor pid=93396)
# (ClientAppActor pid=93396)
# (ClientAppActor pid=93395)
# (ClientAppActor pid=93395)
# (ClientAppActor pid=93397)
# (ClientAppActor pid=93397)
# (ClientAppActor pid=93399)
# (ClientAppActor pid=93399)
# INFO :      aggregate_fit: received 5 results and 0 failures
# WARNING :   No fit_metrics_aggregation_fn provided
# INFO :      fit progress: (1, 569.4270901679993, {'test_accuracy': 0.6778}, 19.98403187491931)
# INFO :      configure_evaluate: strategy sampled 5 clients (out of 5)
# [Round
# INFO :      	History (metrics, centralized):
# INFO :      	{'test_accuracy': [(0, 0.1075),
# INFO :      	                   (1, 0.6778),
# INFO :      	                   (2, 0.7792),
# INFO :      	                   (3, 0.804),
# INFO :      	                   (4, 0.84),
# INFO :      	                   (5, 0.8467),
# INFO :      	                   (6, 0.859),
# INFO :      	                   (7, 0.8665),
# INFO :      	                   (8, 0.8707),
# INFO :      	                   (9, 0.8757),
# INFO :      	                   (10, 0.8787),
# INFO :      	                   (11, 0.8787),
# INFO :      	                   (12, 0.881),
# INFO :      	                   (13, 0.8849),
# INFO :      	                   (14, 0.8841),
# INFO :      	                   (15, 0.8872),
# INFO :      	                   (16, 0.8885),
# INFO :      	                   (17, 0.8895),
# INFO :      	                   (18, 0.8915),
# INFO :      	                   (19, 0.8921),
# INFO :      	                   (20, 0.8915),
# INFO :      	                   (21, 0.8944),
# INFO :      	                   (22, 0.8957),
# INFO :      	                   (23, 0.8959),
# INFO :      	                   (24, 0.8962),
# INFO :      	                   (25, 0.8971),
# INFO :      	                   (26, 0.8991),
# INFO :      	                   (27, 0.8993),
# INFO :      	                   (28, 0.8993),
# INFO :      	                   (29, 0.9001),
# INFO :      	                   (30, 0.9005),
# INFO :      	                   (31, 0.9022),
# INFO :      	                   (32, 0.9021),
# INFO :      	                   (33, 0.9025),
# INFO :      	                   (34, 0.9034),
# INFO :      	                   (35, 0.904),
# INFO :      	                   (36, 0.9049),
# INFO :      	                   (37, 0.9049),
# INFO :      	                   (38, 0.9048),
# INFO :      	                   (39, 0.9068),
# INFO :      	                   (40, 0.9059),
# INFO :      	                   (41, 0.9061),
# INFO :      	                   (42, 0.9072),
# INFO :      	                   (43, 0.908),
# INFO :      	                   (44, 0.9076),
# INFO :      	                   (45, 0.9083),
# INFO :      	                   (46, 0.9083),
# INFO :      	                   (47, 0.9085),
# INFO :      	                   (48, 0.9082),
# INFO :      	                   (49, 0.9091),
# INFO :      	                   (50, 0.9099),
# INFO :      	                   (51, 0.9088),
# INFO :      	                   (52, 0.9086),
# INFO :      	                   (53, 0.9094),
# INFO :      	                   (54, 0.909),
# INFO :      	                   (55, 0.91),
# INFO :      	                   (56, 0.9102),
# INFO :      	                   (57, 0.9107),
# INFO :      	                   (58, 0.9104),
# INFO :      	                   (59, 0.9105),
# INFO :      	                   (60, 0.9112),
# INFO :      	                   (61, 0.9109),
# INFO :      	                   (62, 0.9105),
# INFO :      	                   (63, 0.9105),
# INFO :      	                   (64, 0.911),
# INFO :      	                   (65, 0.9114),
# INFO :      	                   (66, 0.9115),
# INFO :      	                   (67, 0.9128),
# INFO :      	                   (68, 0.9129),
# INFO :      	                   (69, 0.9138),
# INFO :      	                   (70, 0.9134),
# INFO :      	                   (71, 0.913),
# INFO :      	                   (72, 0.9131),
# INFO :      	                   (73, 0.914),
# INFO :      	                   (74, 0.9144),
# INFO :      	                   (75, 0.9146),
# INFO :      	                   (76, 0.9148),
# INFO :      	                   (77, 0.9149),
# INFO :      	                   (78, 0.915),
# INFO :      	                   (79, 0.9148),
# INFO :      	                   (80, 0.9155),
# INFO :      	                   (81, 0.9152),
# INFO :      	                   (82, 0.9154),
# INFO :      	                   (83, 0.9157),
# INFO :      	                   (84, 0.9155),
# INFO :      	                   (85, 0.9151),
# INFO :      	                   (86, 0.9154),
# INFO :      	                   (87, 0.9156),
# INFO :      	                   (88, 0.916),
# INFO :      	                   (89, 0.9159),
# INFO :      	                   (90, 0.9156),
# INFO :      	                   (91, 0.9157),
# INFO :      	                   (92, 0.9165),
# INFO :      	                   (93, 0.9168),
# INFO :      	                   (94, 0.9162),
# INFO :      	                   (95, 0.9178),
# INFO :      	                   (96, 0.9177),
# INFO :      	                   (97, 0.9173),
# INFO :      	                   (98, 0.9171),
# INFO :      	                   (99, 0.9169),
# INFO :      	                   (100, 0.9179)]}
# INFO :

# %% [markdown]
# FEDYOGI WITH FASHIONMNIST- 1 LOCAL ROUND WITH 100 EPOCHS

# %%
import flwr as fl
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
from torch.utils.data import DataLoader, Subset, random_split
import numpy as np
import matplotlib.pyplot as plt

# 1. CNN for FashionMNIST
class FashionCNN(nn.Module):
    def __init__(self, num_classes=10):
        super(FashionCNN, self).__init__()
        self.network = nn.Sequential(
            nn.Conv2d(1, 32, kernel_size=3, padding=1),  # 1-channel input
            nn.ReLU(),
            nn.MaxPool2d(2, 2),
            nn.Conv2d(32, 64, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(2, 2),
            nn.Flatten(),
            nn.Linear(64 * 7 * 7, 128),
            nn.ReLU(),
            nn.Linear(128, num_classes)
        )

    def forward(self, x):
        return self.network(x)

DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# 2. Load FashionMNIST
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.5,), (0.5,))
])

train_dataset = torchvision.datasets.FashionMNIST(root="./data", train=True, download=True, transform=transform)
test_dataset = torchvision.datasets.FashionMNIST(root="./data", train=False, download=True, transform=transform)

# 3. Split data for clients
def get_client_dataloader(client_id, num_clients=5, batch_size=32):
    total_size = len(train_dataset)
    client_size = total_size // num_clients
    indices = list(range(client_id * client_size, (client_id + 1) * client_size))
    subset = Subset(train_dataset, indices)
    train_len = int(0.8 * len(subset))
    val_len = len(subset) - train_len
    train_data, val_data = random_split(subset, [train_len, val_len])
    return (
        DataLoader(train_data, batch_size=batch_size, shuffle=True),
        DataLoader(val_data, batch_size=batch_size, shuffle=False)
    )

testloader = DataLoader(test_dataset, batch_size=32)

# 4. Flower client
class FlowerClient(fl.client.NumPyClient):
    def __init__(self, cid):
        self.cid = int(cid)
        self.model = FashionCNN().to(DEVICE)
        self.trainloader, self.valloader = get_client_dataloader(self.cid)

    def get_parameters(self, config):
        return [val.cpu().numpy() for val in self.model.state_dict().values()]

    def set_parameters(self, parameters):
        state_dict = self.model.state_dict()
        for k, v in zip(state_dict.keys(), parameters):
            state_dict[k] = torch.tensor(v)
        self.model.load_state_dict(state_dict)

    def fit(self, parameters, config):
        self.set_parameters(parameters)
        self.model.train()
        optimizer = optim.Adagrad(self.model.parameters(), lr=0.01)
        criterion = nn.CrossEntropyLoss()
        for _ in range(1):  # One local epoch
            for x, y in self.trainloader:
                x, y = x.to(DEVICE), y.to(DEVICE)
                optimizer.zero_grad()
                output = self.model(x)
                loss = criterion(output, y)
                loss.backward()
                optimizer.step()
        return self.get_parameters({}), len(self.trainloader.dataset), {}

    def evaluate(self, parameters, config):
        self.set_parameters(parameters)
        self.model.eval()
        criterion = nn.CrossEntropyLoss()
        correct, total, loss = 0, 0, 0
        with torch.no_grad():
            for x, y in self.valloader:
                x, y = x.to(DEVICE), y.to(DEVICE)
                out = self.model(x)
                loss += criterion(out, y).item()
                preds = torch.argmax(out, dim=1)
                correct += (preds == y).sum().item()
                total += y.size(0)
        return loss / len(self.valloader), len(self.valloader.dataset), {"val_accuracy": correct / total}

# 5. Evaluation function
test_losses, test_accuracies = [], []

def evaluate_fn(server_round, parameters, config):
    model = FashionCNN().to(DEVICE)
    state_dict = model.state_dict()
    for k, v in zip(state_dict.keys(), parameters):
        state_dict[k] = torch.tensor(v)
    model.load_state_dict(state_dict)
    model.eval()

    correct, total, loss = 0, 0, 0
    criterion = nn.CrossEntropyLoss()
    with torch.no_grad():
        for x, y in testloader:
            x, y = x.to(DEVICE), y.to(DEVICE)
            out = model(x)
            loss += criterion(out, y).item()
            preds = torch.argmax(out, dim=1)
            correct += (preds == y).sum().item()
            total += y.size(0)
    acc = correct / total
    test_losses.append(loss / len(testloader))
    test_accuracies.append(acc)
    print(f"[Round {server_round}] Test Loss: {loss:.4f}, Accuracy: {acc:.4f}")
    return loss, {"test_accuracy": acc}

# 6. Client function
def client_fn(cid: str):
    return FlowerClient(int(cid)).to_client()

# 7. Start simulation
if __name__ == "__main__":
    model = FashionCNN()
    initial_weights = [val.cpu().numpy() for val in model.state_dict().values()]
    initial_parameters = fl.common.ndarrays_to_parameters(initial_weights)

    fl.simulation.start_simulation(
        client_fn=client_fn,
        num_clients=5,
        config=fl.server.ServerConfig(num_rounds=100),
        strategy=fl.server.strategy.FedYogi(
            eta=0.001,
            eta_l=0.01,
            beta_1=0.9,
            beta_2=0.99,
            tau=1e-3,
            fraction_fit=1.0,
            fraction_evaluate=1.0,
            min_fit_clients=5,
            min_evaluate_clients=5,
            min_available_clients=5,
            evaluate_fn=evaluate_fn,
            initial_parameters=initial_parameters,
        ),
    )

    # 8. Save + Plot
    np.save("fashionmnist_fedyogi_accuracies.npy", np.array(test_accuracies))
    np.save("fashionmnist_fedyogi_losses.npy", np.array(test_losses))

    rounds = list(range(1, len(test_losses) + 1))
    plt.figure(figsize=(10, 5))
    plt.plot(rounds, test_losses, marker='o', label="Test Loss")
    plt.plot(rounds, test_accuracies, marker='o', label="Test Accuracy")
    plt.xlabel("Round")
    plt.ylabel("Metric")
    plt.title("FedYogi on FashionMNIST")
    plt.grid(True)
    plt.legend()
    plt.tight_layout()
    plt.savefig("fashionmnist_fedyogi_plot.png")
    plt.show()
# Out:
# WARNING :   DEPRECATED FEATURE: flwr.simulation.start_simulation() is deprecated.
# 	Instead, use the `flwr run` CLI command to start a local simulation in your Flower app, as shown for example below:
#
# 		$ flwr new  # Create a new Flower app from a template
#
# 		$ flwr run  # Run the Flower app in Simulation Mode
#
# 	Using `start_simulation()` is deprecated.
#
#             This is a deprecated feature. It will be removed
#             entirely in future versions of Flower.
#
# INFO :      Starting Flower simulation, config: num_rounds=100, no round_timeout
# 2025-08-01 19:30:31,478	INFO worker.py:1771 -- Started a local Ray instance.
# INFO :      Flower VCE: Ray initialized with resources: {'CPU': 8.0, 'node:__internal_head__': 1.0, 'node:127.0.0.1': 1.0, 'memory': 3087669659.0, 'object_store_memory': 1543834828.0}
# INFO :      Optimize your simulation with Flower VCE: https://flower.ai/docs/framework/how-to-run-simulations.html
# INFO :      No `client_resources` specified. Using minimal resources for clients.
# INFO :      Flower VCE: Resources for each Virtual Client: {'num_cpus': 1, 'num_gpus': 0.0}
# INFO :      Flower VCE: Creating VirtualClientEngineActorPool with 8 actors
# INFO :      [INIT]
# INFO :      Using initial global parameters provided by strategy
# INFO :      Starting evaluation of initial global parameters
# INFO :      initial parameters (loss, other metrics): 722.8613243103027, {'test_accuracy': 0.1101}
# INFO :
# INFO :      [ROUND 1]
# INFO :      configure_fit: strategy sampled 5 clients (out of 5)
# [Round 0] Test Loss: 722.8613, Accuracy: 0.1101
# (ClientAppActor pid=95335) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context`
# (ClientAppActor pid=95335)
# (ClientAppActor pid=95335)             This is a deprecated feature. It will be removed
# (ClientAppActor pid=95335)             entirely in future versions of Flower.
# (ClientAppActor pid=95335)
# (ClientAppActor pid=95337)
# (ClientAppActor pid=95337)
# (ClientAppActor pid=95334)
# (ClientAppActor pid=95334)
# (ClientAppActor pid=95336)
# (ClientAppActor pid=95336)
# (ClientAppActor pid=95338)
# (ClientAppActor pid=95338)
# INFO :      aggregate_fit: received 5 results and 0 failures
# WARNING :   No fit_metrics_aggregation_fn provided
# INFO :      fit progress: (1, 708.8101580142975, {'test_accuracy': 0.3138}, 22.31788683310151)
# INFO :      configure_evaluate: strategy sampled 5 clients (out of 5)
# [Round 1] Test Loss: 708.8102, Accuracy: 0.3138
# (ClientAppActor pid=95335)
# (ClientAppActor pid=95335)
# (ClientAppActor pid=95335) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 5x across cluster]
# (ClientAppActor pid=95335)             This is a deprecated feature. It will be removed [repeated 5x across cluster]
# (ClientAppActor pid=95335)             entirely in future versions of Flower. [repeated 5x across cluster]
# (ClientAppActor pid=95337)
# (ClientAppActor pid=95337)
# (ClientAppActor pid=95336)
# (ClientAppActor pid=95336)
# (ClientAppActor pid=95338)
# (ClientAppActor pid=95338)
# (ClientAppActor pid=95334)
# (ClientAppActor pid=95334)
# INFO :      aggregate_evaluate: received 5 results and 0 failures
# WARNING :   No evaluate_metrics_aggregation_fn provided
# INFO :
# INFO :      [ROUND 2]
# INFO :      configure_fit: strategy sampled 5 clients (out of 5)
# (ClientAppActor pid=95338)
# (ClientAppActor pid=95338)
# (ClientAppActor pid=95334)
# (ClientAppActor pid=95334)
# (ClientAppActor pid=95335)
# (ClientAppActor pid=95335)
# (ClientAppActor pid=95336)
# (ClientAppActor pid=95336)
# (ClientAppActor pid=95337)
# (ClientAppActor pid=95337)
# INFO :      aggregate_fit: received 5 results and 0 failures
# INFO :      fit progress: (2, 692.6873075962067, {'test_accuracy': 0.374}, 33.75081191607751)
# INFO :      configure_evaluate: strategy sampled 5 clients (out of 5)
# [Round 2] Test Loss: 692.6873, Accuracy: 0.3740
# (ClientAppActor pid=95337)
# (ClientAppActor pid=95337)
# (ClientAppActor pid=95337) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 10x across cluster]
# (ClientAppActor pid=95337)             This is a deprecated feature. It will be removed [repeated 10x across cluster]
# (ClientAppActor pid=95337)             entirely in future versions of Flower. [repeated 10x across cluster]
# (ClientAppActor pid=95336)
# (ClientAppActor pid=95336)
# (ClientAppActor pid=95338)
# (ClientAppActor pid=95338)
# (ClientAppActor pid=95334)
# (ClientAppActor pid=95334)
# (ClientAppActor pid=95335)
# (ClientAppActor pid=95335)
# INFO :      aggregate_evaluate: received 5 results and 0 failures
# INFO :
# INFO :      [ROUND 3]
# INFO :      configure_fit: strategy sampled 5 clients (out of 5)
# (ClientAppActor pid=95335)
# (ClientAppActor pid=95335)
# (ClientAppActor pid=95338)
# (ClientAppActor pid=95338)
# (ClientAppActor pid=95334)
# (ClientAppActor pid=95334)
# (ClientAppActor pid=95336)
# (ClientAppActor pid=95336)
# (ClientAppActor pid=95337)
# (ClientAppActor pid=95337)
# INFO :      aggregate_fit: received 5 results and 0 failures
# INFO :      fit progress: (3, 671.4934527873993, {'test_accuracy': 0.567}, 44.75306679098867)
# INFO :      configure_evaluate: strategy sampled 5 clients (out of 5)
# [Round 3] Test Loss: 671.4935, Accuracy: 0.5670
# (ClientAppActor pid=95334)
# (ClientAppActor pid=95334)
# (ClientAppActor pid=95334) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 10x across cluster]
# (ClientAppActor pid=95334)             This is a deprecated feature. It will be removed [repeated 10x across cluster]
# (ClientAppActor pid=95334)             entirely in future versions of Flower. [repeated 10x across cluster]
# (ClientAppActor pid=95337)
# (ClientAppActor pid=95337)
# (ClientAppActor pid=95336)
# (ClientAppActor pid=95336)
# (ClientAppActor pid=95338)
# (ClientAppActor pid=95338)
# (ClientAppActor pid=95335)
# (ClientAppActor pid=95335)
# INFO :      aggregate_evaluate: received 5 results and 0 failures
# INFO :
# INFO :      [ROUND 4]
# INFO :      configure_fit: strategy sampled 5 clients (out of 5)
# (ClientAppActor pid=95335)
# (ClientAppActor pid=95335)
# (ClientAppActor pid=95338)
# (ClientAppActor pid=95338)
# (ClientAppActor pid=95336)
# (ClientAppActor pid=95336)
# (ClientAppActor pid=95337)
# (ClientAppActor pid=95337)
# (ClientAppActor pid=95334)
# (ClientAppActor pid=95334)
# INFO :      aggregate_fit: received 5 results and 0 failures
# INFO :      fit progress: (4, 644.5022487640381, {'test_accuracy': 0.6104}, 56.12605662504211)
# INFO :      configure_evaluate: strategy sampled 5 clients (out of 5)
# [Round 4] Test Loss: 644.5022, Accuracy: 0.6104
# (ClientAppActor pid=95334)
# (ClientAppActor pid=95334)
# (ClientAppActor pid=95334) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 10x across cluster]
# (ClientAppActor pid=95334)             This is a deprecated feature. It will be removed [repeated 10x across cluster]
# (ClientAppActor pid=95334)             entirely in future versions of Flower. [repeated 10x across cluster]
# (ClientAppActor pid=95335)
# (ClientAppActor pid=95335)
# (ClientAppActor pid=95337)
# (ClientAppActor pid=95337)
# (ClientAppActor pid=95338)
# (ClientAppActor pid=95338)
# (ClientAppActor pid=95336)
# (ClientAppActor pid=95336)
# INFO :      aggregate_evaluate: received 5 results and 0 failures
# INFO :
# INFO :      [ROUND 5]
# INFO :      configure_fit: strategy sampled 5 clients (out of 5)
# (ClientAppActor pid=95338)
# (ClientAppActor pid=95338)
# (ClientAppActor pid=95336)
# (ClientAppActor pid=95336)
# (ClientAppActor pid=95335)
# (ClientAppActor pid=95335)
# (ClientAppActor pid=95334)
# (ClientAppActor pid=95334)
# (ClientAppActor pid=95337)
# (ClientAppActor pid=95337)
# INFO :      aggregate_fit: received 5 results and 0 failures
# INFO :      fit progress: (5, 615.2246227264404, {'test_accuracy': 0.6748}, 68.15090004098602)
# INFO :      configure_evaluate: strategy sampled 5 clients (out of 5)
# [Round 5] Test Loss: 615.2246, Accuracy: 0.6748
# (ClientAppActor pid=95337)
# (ClientAppActor pid=95337)
# (ClientAppActor pid=95337) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 10x across cluster]
# (ClientAppActor pid=95337)             This is a deprecated feature. It will be removed [repeated 10x across cluster]
# (ClientAppActor pid=95337)             entirely in future versions of Flower. [repeated 10x across cluster]
# (ClientAppActor pid=95335)
# (ClientAppActor pid=95335)
# (ClientAppActor pid=95334)
# (ClientAppActor pid=95334)
# (ClientAppActor pid=95338)
# (ClientAppActor pid=95338)
# (ClientAppActor pid=95336)
# (ClientAppActor pid=95336)
# INFO :      aggregate_evaluate: received 5 results and 0 failures
# INFO :
# INFO :      [ROUND 6]
# INFO :      configure_fit: strategy sampled 5 clients (out of 5)
# (ClientAppActor pid=95338)
# (ClientAppActor pid=95338)
# (ClientAppActor pid=95336)
# (ClientAppActor pid=95336)
# (ClientAppActor pid=95334)
# (ClientAppActor pid=95334)
# (ClientAppActor pid=95335)
# (ClientAppActor pid=95335)
# (ClientAppActor pid=95337)
# (ClientAppActor pid=95337)
# INFO :      aggregate_fit: received 5 results and 0 failures
# INFO :      fit progress: (6, 584.2108877897263, {'test_accuracy': 0.6938}, 80.95179616613314)
# INFO :      configure_evaluate: strategy sampled 5 clients (out of 5)
# [Round 6] Test Loss: 584.2109, Accuracy: 0.6938
# (ClientAppActor pid=95337)
# (ClientAppActor pid=95337)
# (ClientAppActor pid=95337) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 10x across cluster]
# (ClientAppActor pid=95337)             This is a deprecated feature. It will be removed [repeated 10x across cluster]
# (ClientAppActor pid=95337)             entirely in future versions of Flower. [repeated 10x across cluster]
# (ClientAppActor pid=95338)
# (ClientAppActor pid=95338)
# (ClientAppActor pid=95335)
# (ClientAppActor pid=95335)
# (ClientAppActor pid=95336)
# (ClientAppActor pid=95336)
# (ClientAppActor pid=95334)
# (ClientAppActor pid=95334)
# INFO :      aggregate_evaluate: received 5 results and 0 failures
# INFO :
# INFO :      [ROUND 7]
# INFO :      configure_fit: strategy sampled 5 clients (out of 5)
# (ClientAppActor pid=95334)
# (ClientAppActor pid=95334)
# (ClientAppActor pid=95336)
# (ClientAppActor pid=95336)
# (ClientAppActor pid=95335)
# (ClientAppActor pid=95335)
# (ClientAppActor pid=95338)
# (ClientAppActor pid=95338)
# (ClientAppActor pid=95337)
# (ClientAppActor pid=95337)
# INFO :      aggregate_fit: received 5 results and 0 failures
# INFO :      fit progress: (7, 551.9428852796555, {'test_accuracy': 0.709}, 92.56414612499066)
# INFO :      configure_evaluate: strategy sampled 5 clients (out of 5)
# [Round 7] Test Loss: 551.9429, Accuracy: 0.7090
# (ClientAppActor pid=95335)
# (ClientAppActor pid=95335)
# (ClientAppActor pid=95335) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 10x across cluster]
# (ClientAppActor pid=95335)             This is a deprecated feature. It will be removed [repeated 10x across cluster]
# (ClientAppActor pid=95335)             entirely in future versions of Flower. [repeated 10x across cluster]
# (ClientAppActor pid=95338)
# (ClientAppActor pid=95338)
# (ClientAppActor pid=95337)
# (ClientAppActor pid=95337)
# (ClientAppActor pid=95336)
# (ClientAppActor pid=95336)
# (ClientAppActor pid=95334)
# (ClientAppActor pid=95334)
# INFO :      aggregate_evaluate: received 5 results and 0 failures
# INFO :
# INFO :      [ROUND 8]
# INFO :      configure_fit: strategy sampled 5 clients (out of 5)
# (ClientAppActor pid=95334)
# (ClientAppActor pid=95334)
# (ClientAppActor pid=95335)
# (ClientAppActor pid=95335)
# (ClientAppActor pid=95337)
# (ClientAppActor pid=95337)
# (ClientAppActor pid=95336)
# (ClientAppActor pid=95336)
# (ClientAppActor pid=95338)
# (ClientAppActor pid=95338)
# INFO :      aggregate_fit: received 5 results and 0 failures
# INFO :      fit progress: (8, 516.9336578845978, {'test_accuracy': 0.7174}, 103.8714615830686)
# INFO :      configure_evaluate: strategy sampled 5 clients (out of 5)
# [Round
# INFO :      	                   (20, 0.8384),
# INFO :      	                   (21, 0.8442),
# INFO :      	                   (22, 0.8473),
# INFO :      	                   (23, 0.852),
# INFO :      	                   (24, 0.856),
# INFO :      	                   (25, 0.8592),
# INFO :      	                   (26, 0.8619),
# INFO :      	                   (27, 0.863),
# INFO :      	                   (28, 0.8662),
# INFO :      	                   (29, 0.8673),
# INFO :      	                   (30, 0.8679),
# INFO :      	                   (31, 0.869),
# INFO :      	                   (32, 0.8698),
# INFO :      	                   (33, 0.8717),
# INFO :      	                   (34, 0.8731),
# INFO :      	                   (35, 0.8748),
# INFO :      	                   (36, 0.8761),
# INFO :      	                   (37, 0.8767),
# INFO :      	                   (38, 0.877),
# INFO :      	                   (39, 0.8787),
# INFO :      	                   (40, 0.8798),
# INFO :      	                   (41, 0.8804),
# INFO :      	                   (42, 0.8812),
# INFO :      	                   (43, 0.8824),
# INFO :      	                   (44, 0.8839),
# INFO :      	                   (45, 0.8854),
# INFO :      	                   (46, 0.8858),
# INFO :      	                   (47, 0.8867),
# INFO :      	                   (48, 0.8866),
# INFO :      	                   (49, 0.8866),
# INFO :      	                   (50, 0.8872),
# INFO :      	                   (51, 0.8876),
# INFO :      	                   (52, 0.8882),
# INFO :      	                   (53, 0.8883),
# INFO :      	                   (54, 0.8888),
# INFO :      	                   (55, 0.8891),
# INFO :      	                   (56, 0.8897),
# INFO :      	                   (57, 0.8901),
# INFO :      	                   (58, 0.8909),
# INFO :      	                   (59, 0.8909),
# INFO :      	                   (60, 0.8915),
# INFO :      	                   (61, 0.8917),
# INFO :      	                   (62, 0.8927),
# INFO :      	                   (63, 0.8929),
# INFO :      	                   (64, 0.8933),
# INFO :      	                   (65, 0.8939),
# INFO :      	                   (66, 0.8943),
# INFO :      	                   (67, 0.895),
# INFO :      	                   (68, 0.8954),
# INFO :      	                   (69, 0.8958),
# INFO :      	                   (70, 0.8965),
# INFO :      	                   (71, 0.8968),
# INFO :      	                   (72, 0.8973),
# INFO :      	                   (73, 0.8982),
# INFO :      	                   (74, 0.8986),
# INFO :      	                   (75, 0.8988),
# INFO :      	                   (76, 0.899),
# INFO :      	                   (77, 0.8999),
# INFO :      	                   (78, 0.8998),
# INFO :      	                   (79, 0.8999),
# INFO :      	                   (80, 0.9004),
# INFO :      	                   (81, 0.901),
# INFO :      	                   (82, 0.9016),
# INFO :      	                   (83, 0.9017),
# INFO :      	                   (84, 0.9018),
# INFO :      	                   (85, 0.9019),
# INFO :      	                   (86, 0.9019),
# INFO :      	                   (87, 0.902),
# INFO :      	                   (88, 0.9018),
# INFO :      	                   (89, 0.9021),
# INFO :      	                   (90, 0.9017),
# INFO :      	                   (91, 0.9022),
# INFO :      	                   (92, 0.9022),
# INFO :      	                   (93, 0.9024),
# INFO :      	                   (94, 0.9027),
# INFO :      	                   (95, 0.9028),
# INFO :      	                   (96, 0.9033),
# INFO :      	                   (97, 0.9037),
# INFO :      	                   (98, 0.9045),
# INFO :      	                   (99, 0.9047),
# INFO :      	                   (100, 0.9051)]}
# INFO :

# %% [markdown]
# FEDAVG WITH FASHIONMNIST- 1 LOCAL EPOCH WITH 100 ROUNDS

# %%
import flwr as fl
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, random_split, Subset
import numpy as np
import matplotlib.pyplot as plt
from torchvision import datasets, transforms

# Dataset setup: FashionMNIST
transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.5,), (0.5,))
])

train_dataset = datasets.FashionMNIST(root="./data", train=True, download=True, transform=transform)
test_dataset = datasets.FashionMNIST(root="./data", train=False, download=True, transform=transform)

DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# CNN Model for FashionMNIST
class SimpleCNN(nn.Module):
    def __init__(self, in_channels=1, num_classes=10):
        super(SimpleCNN, self).__init__()
        self.network = nn.Sequential(
            nn.Conv2d(in_channels, 32, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(2),
            nn.Conv2d(32, 64, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(2),
            nn.Flatten(),
            nn.Linear(64 * 7 * 7, 128),
            nn.ReLU(),
            nn.Linear(128, num_classes)
        )

    def forward(self, x):
        return self.network(x)

# Client data loader
def get_client_dataloader(client_id, num_clients=5, batch_size=32):
    total_size = len(train_dataset)
    client_size = total_size // num_clients
    indices = list(range(client_id * client_size, (client_id + 1) * client_size))
    subset = Subset(train_dataset, indices)
    train_len = int(0.8 * len(subset))
    val_len = len(subset) - train_len
    train_data, val_data = random_split(subset, [train_len, val_len])
    return (
        DataLoader(train_data, batch_size=batch_size, shuffle=True),
        DataLoader(val_data, batch_size=batch_size, shuffle=False),
    )

testloader = DataLoader(test_dataset, batch_size=32)

# Flower Client
class FlowerClient(fl.client.NumPyClient):
    def __init__(self, cid):
        self.cid = cid
        self.model = SimpleCNN(in_channels=1, num_classes=10).to(DEVICE)
        self.trainloader, self.valloader = get_client_dataloader(cid)

    def get_parameters(self, config):
        return [val.cpu().numpy() for val in self.model.state_dict().values()]

    def set_parameters(self, parameters):
        state_dict = self.model.state_dict()
        for k, v in zip(state_dict.keys(), parameters):
            state_dict[k] = torch.tensor(v)
        self.model.load_state_dict(state_dict)

    def fit(self, parameters, config):
        self.set_parameters(parameters)
        self.model.train()
        optimizer = optim.SGD(self.model.parameters(), lr=0.01)
        criterion = nn.CrossEntropyLoss()
        for x, y in self.trainloader:
            x, y = x.to(DEVICE), y.to(DEVICE)
            optimizer.zero_grad()
            out = self.model(x)
            loss = criterion(out, y)
            loss.backward()
            optimizer.step()
        return self.get_parameters({}), len(self.trainloader.dataset), {}

    def evaluate(self, parameters, config):
        self.set_parameters(parameters)
        self.model.eval()
        criterion = nn.CrossEntropyLoss()
        correct, loss, total = 0, 0, 0
        with torch.no_grad():
            for x, y in self.valloader:
                x, y = x.to(DEVICE), y.to(DEVICE)
                out = self.model(x)
                loss += criterion(out, y).item()
                pred = torch.argmax(out, dim=1)
                correct += (pred == y).sum().item()
                total += y.size(0)
        return loss / len(self.valloader), len(self.valloader.dataset), {"val_accuracy": correct / total}

# Client factory
def client_fn(cid: str):
    return FlowerClient(int(cid)).to_client()

# Server-side evaluation
test_losses, test_accuracies = [], []

def evaluate_fn(server_round, parameters, config):
    model = SimpleCNN(in_channels=1, num_classes=10).to(DEVICE)
    state_dict = model.state_dict()
    for k, v in zip(state_dict.keys(), parameters):
        state_dict[k] = torch.tensor(v)
    model.load_state_dict(state_dict)
    model.eval()

    criterion = nn.CrossEntropyLoss()
    correct, total, loss = 0, 0, 0

    with torch.no_grad():
        for x, y in testloader:
            x, y = x.to(DEVICE), y.to(DEVICE)
            out = model(x)
            loss += criterion(out, y).item()
            pred = torch.argmax(out, dim=1)
            correct += (pred == y).sum().item()
            total += y.size(0)

    accuracy = correct / total
    avg_loss = loss / len(testloader)
    test_losses.append(avg_loss)
    test_accuracies.append(accuracy)

    print(f"Round {server_round}: Test Loss = {avg_loss:.4f}, Accuracy = {accuracy:.4f}")
    return avg_loss, {"test_accuracy": accuracy}

# Run Federated Simulation
if __name__ == "__main__":
    model = SimpleCNN(in_channels=1, num_classes=10)
    initial_weights = [val.cpu().numpy() for val in model.state_dict().values()]
    initial_parameters = fl.common.ndarrays_to_parameters(initial_weights)

    fl.simulation.start_simulation(
        client_fn=client_fn,
        num_clients=5,
        config=fl.server.ServerConfig(num_rounds=100),
        strategy=fl.server.strategy.FedAvg(
            fraction_fit=1.0,
            fraction_evaluate=1.0,
            min_fit_clients=5,
            min_evaluate_clients=5,
            min_available_clients=5,
            evaluate_fn=evaluate_fn,
            initial_parameters=initial_parameters,
        ),
    )

    # Save metrics
    np.save("fashionmnist_fedavg_test_accuracies.npy", np.array(test_accuracies))
    np.save("fashionmnist_fedavg_test_losses.npy", np.array(test_losses))

    # Plot results
    rounds = list(range(1, len(test_losses) + 1))
    fig, ax1 = plt.subplots(figsize=(10, 5))

    ax1.set_xlabel("Round")
    ax1.set_ylabel("Test Loss")
    line1, = ax1.plot(rounds, test_losses, marker='o', label="Test Loss")
    ax1.tick_params(axis='y')

    ax2 = ax1.twinx()
    ax2.set_ylabel("Test Accuracy")
    line2, = ax2.plot(rounds, test_accuracies, marker='o', label="Test Accuracy")
    ax2.tick_params(axis='y')

    lines = [line1, line2]
    labels = [line.get_label() for line in lines]
    ax1.legend(lines, labels, loc='upper right')

    plt.title("FedAvg on FashionMNIST")
    fig.tight_layout()
    plt.savefig("fashionmnist_fedavg_metrics.png")
    plt.show()
# Out:
# WARNING :   DEPRECATED FEATURE: flwr.simulation.start_simulation() is deprecated.
# 	Instead, use the `flwr run` CLI command to start a local simulation in your Flower app, as shown for example below:
#
# 		$ flwr new  # Create a new Flower app from a template
#
# 		$ flwr run  # Run the Flower app in Simulation Mode
#
# 	Using `start_simulation()` is deprecated.
#
#             This is a deprecated feature. It will be removed
#             entirely in future versions of Flower.
#
# INFO :      Starting Flower simulation, config: num_rounds=100, no round_timeout
# 2025-08-01 20:03:33,797	INFO worker.py:1771 -- Started a local Ray instance.
# INFO :      Flower VCE: Ray initialized with resources: {'node:127.0.0.1': 1.0, 'object_store_memory': 1381348147.0, 'memory': 2762696295.0, 'CPU': 8.0, 'node:__internal_head__': 1.0}
# INFO :      Optimize your simulation with Flower VCE: https://flower.ai/docs/framework/how-to-run-simulations.html
# INFO :      No `client_resources` specified. Using minimal resources for clients.
# INFO :      Flower VCE: Resources for each Virtual Client: {'num_cpus': 1, 'num_gpus': 0.0}
# INFO :      Flower VCE: Creating VirtualClientEngineActorPool with 8 actors
# INFO :      [INIT]
# INFO :      Using initial global parameters provided by strategy
# INFO :      Starting evaluation of initial global parameters
# INFO :      initial parameters (loss, other metrics): 2.301485268833538, {'test_accuracy': 0.0646}
# INFO :
# INFO :      [ROUND 1]
# INFO :      configure_fit: strategy sampled 5 clients (out of 5)
# Round 0: Test Loss = 2.3015, Accuracy = 0.0646
# (ClientAppActor pid=96225) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context`
# (ClientAppActor pid=96225)
# (ClientAppActor pid=96225)             This is a deprecated feature. It will be removed
# (ClientAppActor pid=96225)             entirely in future versions of Flower.
# (ClientAppActor pid=96225)
# (ClientAppActor pid=96223)
# (ClientAppActor pid=96223)
# (ClientAppActor pid=96224)
# (ClientAppActor pid=96224)
# (ClientAppActor pid=96227)
# (ClientAppActor pid=96227)
# (ClientAppActor pid=96226)
# (ClientAppActor pid=96226)
# INFO :      aggregate_fit: received 5 results and 0 failures
# WARNING :   No fit_metrics_aggregation_fn provided
# INFO :      fit progress: (1, 0.7588280393673589, {'test_accuracy': 0.7377}, 17.68224670807831)
# INFO :      configure_evaluate: strategy sampled 5 clients (out of 5)
# Round 1: Test Loss = 0.7588, Accuracy = 0.7377
# (ClientAppActor pid=96223)
# (ClientAppActor pid=96223)
# (ClientAppActor pid=96223) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 5x across cluster]
# (ClientAppActor pid=96223)             This is a deprecated feature. It will be removed [repeated 5x across cluster]
# (ClientAppActor pid=96223)             entirely in future versions of Flower. [repeated 5x across cluster]
# (ClientAppActor pid=96227)
# (ClientAppActor pid=96227)
# (ClientAppActor pid=96226)
# (ClientAppActor pid=96226)
# (ClientAppActor pid=96225)
# (ClientAppActor pid=96225)
# (ClientAppActor pid=96224)
# (ClientAppActor pid=96224)
# INFO :      aggregate_evaluate: received 5 results and 0 failures
# WARNING :   No evaluate_metrics_aggregation_fn provided
# INFO :
# INFO :      [ROUND 2]
# INFO :      configure_fit: strategy sampled 5 clients (out of 5)
# (ClientAppActor pid=96224)
# (ClientAppActor pid=96224)
# (ClientAppActor pid=96225)
# (ClientAppActor pid=96225)
# (ClientAppActor pid=96226)
# (ClientAppActor pid=96226)
# (ClientAppActor pid=96223)
# (ClientAppActor pid=96223)
# (ClientAppActor pid=96227)
# (ClientAppActor pid=96227)
# INFO :      aggregate_fit: received 5 results and 0 failures
# INFO :      fit progress: (2, 0.6262261391447755, {'test_accuracy': 0.7665}, 28.853382625151426)
# INFO :      configure_evaluate: strategy sampled 5 clients (out of 5)
# Round 2: Test Loss = 0.6262, Accuracy = 0.7665
# (ClientAppActor pid=96223)
# (ClientAppActor pid=96223)
# (ClientAppActor pid=96223) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 10x across cluster]
# (ClientAppActor pid=96223)             This is a deprecated feature. It will be removed [repeated 10x across cluster]
# (ClientAppActor pid=96223)             entirely in future versions of Flower. [repeated 10x across cluster]
# (ClientAppActor pid=96227)
# (ClientAppActor pid=96227)
# (ClientAppActor pid=96225)
# (ClientAppActor pid=96225)
# (ClientAppActor pid=96226)
# (ClientAppActor pid=96226)
# (ClientAppActor pid=96224)
# (ClientAppActor pid=96224)
# INFO :      aggregate_evaluate: received 5 results and 0 failures
# INFO :
# INFO :      [ROUND 3]
# INFO :      configure_fit: strategy sampled 5 clients (out of 5)
# (ClientAppActor pid=96224)
# (ClientAppActor pid=96224)
# (ClientAppActor pid=96226)
# (ClientAppActor pid=96226)
# (ClientAppActor pid=96225)
# (ClientAppActor pid=96225)
# (ClientAppActor pid=96223)
# (ClientAppActor pid=96223)
# (ClientAppActor pid=96227)
# (ClientAppActor pid=96227)
# INFO :      aggregate_fit: received 5 results and 0 failures
# INFO :      fit progress: (3, 0.5642880342258051, {'test_accuracy': 0.7905}, 40.169575416948646)
# INFO :      configure_evaluate: strategy sampled 5 clients (out of 5)
# Round 3: Test Loss = 0.5643, Accuracy = 0.7905
# (ClientAppActor pid=96223)
# (ClientAppActor pid=96223)
# (ClientAppActor pid=96223) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 10x across cluster]
# (ClientAppActor pid=96223)             This is a deprecated feature. It will be removed [repeated 10x across cluster]
# (ClientAppActor pid=96223)             entirely in future versions of Flower. [repeated 10x across cluster]
# (ClientAppActor pid=96225)
# (ClientAppActor pid=96225)
# (ClientAppActor pid=96227)
# (ClientAppActor pid=96227)
# (ClientAppActor pid=96226)
# (ClientAppActor pid=96226)
# (ClientAppActor pid=96224)
# (ClientAppActor pid=96224)
# INFO :      aggregate_evaluate: received 5 results and 0 failures
# INFO :
# INFO :      [ROUND 4]
# INFO :      configure_fit: strategy sampled 5 clients (out of 5)
# (ClientAppActor pid=96224)
# (ClientAppActor pid=96224)
# (ClientAppActor pid=96226)
# (ClientAppActor pid=96226)
# (ClientAppActor pid=96225)
# (ClientAppActor pid=96225)
# (ClientAppActor pid=96227)
# (ClientAppActor pid=96227)
# (ClientAppActor pid=96223)
# (ClientAppActor pid=96223)
# INFO :      aggregate_fit: received 5 results and 0 failures
# INFO :      fit progress: (4, 0.524788098927504, {'test_accuracy': 0.8105}, 51.984861416975036)
# INFO :      configure_evaluate: strategy sampled 5 clients (out of 5)
# Round 4: Test Loss = 0.5248, Accuracy = 0.8105
# (ClientAppActor pid=96225)
# (ClientAppActor pid=96225)
# (ClientAppActor pid=96225) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 10x across cluster]
# (ClientAppActor pid=96225)             This is a deprecated feature. It will be removed [repeated 10x across cluster]
# (ClientAppActor pid=96225)             entirely in future versions of Flower. [repeated 10x across cluster]
# (ClientAppActor pid=96223)
# (ClientAppActor pid=96223)
# (ClientAppActor pid=96227)
# (ClientAppActor pid=96227)
# (ClientAppActor pid=96224)
# (ClientAppActor pid=96224)
# (ClientAppActor pid=96226)
# (ClientAppActor pid=96226)
# INFO :      aggregate_evaluate: received 5 results and 0 failures
# INFO :
# INFO :      [ROUND 5]
# INFO :      configure_fit: strategy sampled 5 clients (out of 5)
# (ClientAppActor pid=96224)
# (ClientAppActor pid=96224)
# (ClientAppActor pid=96226)
# (ClientAppActor pid=96226)
# (ClientAppActor pid=96227)
# (ClientAppActor pid=96227)
# (ClientAppActor pid=96225)
# (ClientAppActor pid=96225)
# (ClientAppActor pid=96223)
# (ClientAppActor pid=96223)
# INFO :      aggregate_fit: received 5 results and 0 failures
# INFO :      fit progress: (5, 0.4925922882347442, {'test_accuracy': 0.8197}, 64.80077537498437)
# INFO :      configure_evaluate: strategy sampled 5 clients (out of 5)
# Round 5: Test Loss = 0.4926, Accuracy = 0.8197
# (ClientAppActor pid=96225)
# (ClientAppActor pid=96225)
# (ClientAppActor pid=96225) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 10x across cluster]
# (ClientAppActor pid=96225)             This is a deprecated feature. It will be removed [repeated 10x across cluster]
# (ClientAppActor pid=96225)             entirely in future versions of Flower. [repeated 10x across cluster]
# (ClientAppActor pid=96223)
# (ClientAppActor pid=96223)
# (ClientAppActor pid=96227)
# (ClientAppActor pid=96227)
# (ClientAppActor pid=96226)
# (ClientAppActor pid=96226)
# (ClientAppActor pid=96224)
# (ClientAppActor pid=96224)
# INFO :      aggregate_evaluate: received 5 results and 0 failures
# INFO :
# INFO :      [ROUND 6]
# INFO :      configure_fit: strategy sampled 5 clients (out of 5)
# (ClientAppActor pid=96224)
# (ClientAppActor pid=96224)
# (ClientAppActor pid=96227)
# (ClientAppActor pid=96227)
# (ClientAppActor pid=96226)
# (ClientAppActor pid=96226)
# (ClientAppActor pid=96225)
# (ClientAppActor pid=96225)
# (ClientAppActor pid=96223)
# (ClientAppActor pid=96223)
# INFO :      aggregate_fit: received 5 results and 0 failures
# INFO :      fit progress: (6, 0.46416455431106374, {'test_accuracy': 0.8339}, 76.76456687506288)
# INFO :      configure_evaluate: strategy sampled 5 clients (out of 5)
# Round 6: Test Loss = 0.4642, Accuracy = 0.8339
# (ClientAppActor pid=96225)
# (ClientAppActor pid=96225)
# (ClientAppActor pid=96225) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 10x across cluster]
# (ClientAppActor pid=96225)             This is a deprecated feature. It will be removed [repeated 10x across cluster]
# (ClientAppActor pid=96225)             entirely in future versions of Flower. [repeated 10x across cluster]
# (ClientAppActor pid=96223)
# (ClientAppActor pid=96223)
# (ClientAppActor pid=96227)
# (ClientAppActor pid=96227)
# (ClientAppActor pid=96226)
# (ClientAppActor pid=96226)
# (ClientAppActor pid=96224)
# (ClientAppActor pid=96224)
# INFO :      aggregate_evaluate: received 5 results and 0 failures
# INFO :
# INFO :      [ROUND 7]
# INFO :      configure_fit: strategy sampled 5 clients (out of 5)
# (ClientAppActor pid=96224)
# (ClientAppActor pid=96224)
# (ClientAppActor pid=96226)
# (ClientAppActor pid=96226)
# (ClientAppActor pid=96227)
# (ClientAppActor pid=96227)
# (ClientAppActor pid=96223)
# (ClientAppActor pid=96223)
# (ClientAppActor pid=96225)
# (ClientAppActor pid=96225)
# INFO :      aggregate_fit: received 5 results and 0 failures
# INFO :      fit progress: (7, 0.4484254799711819, {'test_accuracy': 0.8367}, 88.38722529215738)
# INFO :      configure_evaluate: strategy sampled 5 clients (out of 5)
# Round 7: Test Loss = 0.4484, Accuracy = 0.8367
# (ClientAppActor pid=96225)
# (ClientAppActor pid=96225)
# (ClientAppActor pid=96225) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 10x across cluster]
# (ClientAppActor pid=96225)             This is a deprecated feature. It will be removed [repeated 10x across cluster]
# (ClientAppActor pid=96225)             entirely in future versions of Flower. [repeated 10x across cluster]
# (ClientAppActor pid=96223)
# (ClientAppActor pid=96223)
# (ClientAppActor pid=96227)
# (ClientAppActor pid=96227)
# (ClientAppActor pid=96226)
# (ClientAppActor pid=96226)
# (ClientAppActor pid=96224)
# (ClientAppActor pid=96224)
# INFO :      aggregate_evaluate: received 5 results and 0 failures
# INFO :
# INFO :      [ROUND 8]
# INFO :      configure_fit: strategy sampled 5 clients (out of 5)
# (ClientAppActor pid=96224)
# (ClientAppActor pid=96224)
# (ClientAppActor pid=96227)
# (ClientAppActor pid=96227)
# (ClientAppActor pid=96226)
# (ClientAppActor pid=96226)
# (ClientAppActor pid=96225)
# (ClientAppActor pid=96225)
# (ClientAppActor pid=96223)
# (ClientAppActor pid=96223)
# INFO :      aggregate_fit: received 5 results and 0 failures
# INFO :      fit progress: (8, 0.42890002695135415, {'test_accuracy': 0.8456}, 100.64364033308811)
# INFO :      configure_evaluate: strategy sampled 5 clients (out of 5)
# Round 8: Test Loss = 0.4289, Accuracy = 0.8456
# (ClientAppActor pid=96225)
# (ClientAppActor pid=96225)
# (ClientAppActor pid=96225) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 10x across cluster]
# (ClientAppActor pid=96225)             This is a deprecated feature. It will be removed [repeated 10x across cluster]
# (ClientAppActor pid=96225)             entirely in future versions of Flower. [repeated 10x across cluster]
# (ClientAppActor pid=96223)
# (ClientAppActor pid=96223)
# (ClientAppActor pid=96227)
# (ClientAppActor pid=96227)
# (ClientAppActor pid=96224)
# (ClientAppActor pid=96224)
# (ClientAppActor pid=96226)
# (ClientAppActor pid=96226)
# INFO :      aggregate_evaluate: received 5 results and 0 failures
# INFO :
# INFO :      [ROUND 9]
# INFO :      configure_fit: strategy sampled 5 clients (out of 5)
# (ClientAppActor pid=96224)
# (ClientAppActor pid=96224)
# (ClientAppActor pid=96227)
# (ClientAppActor pid=96227)
# (ClientAppActor pid=96226)
# (ClientAppActor pid=96226)
# (ClientAppActor pid=96223)
# (ClientAppActor pid=96223)
# (ClientAppActor pid=96225)
# (ClientAppActor pid=96225)
# INFO :      aggregate_fit: received 5 results and 0 failures
# INFO :      fit progress: (9, 0.4146271730526187, {'test_accuracy': 0.8508}, 115.69538820814341)
# INFO :      configure_evaluate: strategy sampled 5 clients (out of 5)
# Round 9: Test Loss = 0.4146, Accuracy = 0.8508
# (ClientAppActor pid=96225)
# (ClientAppActor pid=96225)
# (ClientAppActor pid=96225) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 10x across cluster]
# (ClientAppActor pid=96225)             This is a deprecated feature. It will be removed [repeated 10x across cluster]
# (ClientAppActor pid=96225)             entirely in future versions of Flower. [repeated 10x across cluster]
# (ClientAppActor pid=96223)
# (ClientAppActor pid=96223)
# (ClientAppActor pid=96227)
# (ClientAppActor pid=96227)
# (ClientAppActor pid=96226)
# (ClientAppActor pid=96226)
# (ClientAppActor pid=96224)
# (ClientAppActor pid=96224)
# INFO :      aggregate_evaluate: received 5 results and 0 failures
# INFO :
# INFO :      [ROUND 10]
# INFO :      configure_fit: strategy sampled 5 clients (out of 5)
# (ClientAppActor pid=96224)
# (ClientAppActor pid=96224)
# (ClientAppActor pid=96226)
# (ClientAppActor pid=96226)
# (ClientAppActor pid=96227)
# (ClientAppActor pid=96227)
# (ClientAppActor pid=96223)
# (ClientAppActor pid=96223)
# (ClientAppActor pid=96225)
# (ClientAppActor pid=96225)
# INFO :      aggregate_fit: received 5 results and 0 failures
# INFO :      fit progress: (10, 0.40841730510274443, {'test_accuracy': 0.8503}, 128.8446820001118)
# INFO :      configure_evaluate: strategy sampled 5 clients (out of 5)
# Round 10: Test Loss = 0.4084, Accuracy = 0.8503
# (ClientAppActor pid=96225)
# (ClientAppActor pid=96225)
# (ClientAppActor pid=96225) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 10x across cluster]
# (ClientAppActor pid=96225)             This is a deprecated feature. It will be removed [repeated 10x across cluster]
# (ClientAppActor pid=96225)             entirely in future versions of Flower. [repeated 10x across cluster]
# (ClientAppActor pid=96223)
# (ClientAppActor pid=96223)
# (ClientAppActor pid=96227)
# (ClientAppActor pid=96227)
# (ClientAppActor pid=96226)
# (ClientAppActor pid=96226)
# (ClientAppActor pid=96224)
# (ClientAppActor pid=96224)
# INFO :      aggregate_evaluate: received 5 results and 0 failures
# INFO :
# INFO :      [ROUND 11]
# INFO :      configure_fit: strategy sampled 5 clients (out of 5)
# (ClientAppActor pid=96223)
# (ClientAppActor pid=96223)
# (ClientAppActor pid=96224)
# (ClientAppActor pid=96224)
# (ClientAppActor pid=96226)
# (ClientAppActor pid=96226)
# (ClientAppActor pid=96225)
# (ClientAppActor pid=96225)
# (ClientAppActor pid=96227)
# (ClientAppActor pid=96227)
# INFO :      aggregate_fit: received 5 results and 0 failures
# INFO :      fit progress: (11, 0.4021484621654684, {'test_accuracy': 0.856}, 140.97748729214072)
# INFO :      configure_evaluate: strategy sampled 5 clients (out of 5)
# Round 11: Test Loss = 0.4021, Accuracy = 0.8560
# (ClientAppActor pid=96225)
# (ClientAppActor pid=96225)
# (ClientAppActor pid=96225) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 10x across cluster]
# (ClientAppActor pid=96225)             This is a deprecated feature. It will be removed [repeated 10x across cluster]
# (ClientAppActor pid=96225)             entirely in future versions of Flower. [repeated 10x across cluster]
# (ClientAppActor pid=96227)
# (ClientAppActor pid=96227)
# (ClientAppActor pid=96224)
# (ClientAppActor pid=96224)
# (ClientAppActor pid=96226)
# (ClientAppActor pid=96226)
# (ClientAppActor pid=96223)
# (ClientAppActor pid=96223)
# INFO :      aggregate_evaluate: received 5 results and 0 failures
# INFO :
# INFO :      [ROUND 12]
# INFO :      configure_fit: strategy sampled 5 clients (out of 5)
# (ClientAppActor pid=96223)
# (ClientAppActor pid=96223)
# (ClientAppActor pid=96224)
# (ClientAppActor pid=96224)
# (ClientAppActor pid=96226)
# (ClientAppActor pid=96226)
# (ClientAppActor pid=96225)
# (ClientAppActor pid=96225)
# (ClientAppActor pid=96227)
# (ClientAppActor pid=96227)
# INFO :      aggregate_fit: received 5 results and 0 failures
# INFO :      fit progress: (12, 0.3887935629287086, {'test_accuracy': 0.8601}, 154.06035529216751)
# INFO :      configure_evaluate: strategy sampled 5 clients (out of 5)
# Round
# INFO :      		round 52: 0.2798303330358796
# INFO :      		round 53: 0.2816716478274653
# INFO :      		round 54: 0.28088715603462044
# INFO :      		round 55: 0.28803839039402646
# INFO :      		round 56: 0.2784051478456575
# INFO :      		round 57: 0.2782040831808465
# INFO :      		round 58: 0.27319389848282544
# INFO :      		round 59: 0.2744497453537993
# INFO :      		round 60: 0.27636163948347775
# INFO :      		round 61: 0.2699526287139224
# INFO :      		round 62: 0.27173349740929875
# INFO :      		round 63: 0.27084099532316286
# INFO :      		round 64: 0.2699202525491913
# INFO :      		round 65: 0.2688160203159236
# INFO :      		round 66: 0.26758814259125785
# INFO :      		round 67: 0.26815664867004646
# INFO :      		round 68: 0.26434267559847513
# INFO :      		round 69: 0.26487156561912056
# INFO :      		round 70: 0.26464438418777414
# INFO :      		round 71: 0.26348985518557955
# INFO :      		round 72: 0.2678671948873578
# INFO :      		round 73: 0.2632027654506909
# INFO :      		round 74: 0.2604680777119752
# INFO :      		round 75: 0.2622788808287713
# INFO :      		round 76: 0.2638891083530534
# INFO :      		round 77: 0.25891262663605685
# INFO :      		round 78: 0.25896304364973743
# INFO :      		round 79: 0.25972744267874254
# INFO :      		round 80: 0.2565639637374935
# INFO :      		round 81: 0.2582197553885821
# INFO :      		round 82: 0.25548528475811877
# INFO :      		round 83: 0.2582176604126684
# INFO :      		round 84: 0.254800261536869
# INFO :      		round 85: 0.2539216952856642
# INFO :      		round 86: 0.2531792882401437
# INFO :      		round 87: 0.2511961970823451
# INFO :      		round 88: 0.25690767761117544
# INFO :      		round 89: 0.253796624442259
# INFO :      		round 90: 0.2533872751191782
# INFO :      		round 91: 0.25141995832228814
# INFO :      		round 92: 0.24938249461852705
# INFO :      		round 93: 0.2501584798061905
# INFO :      		round 94: 0.24871351796621904
# INFO :      		round 95: 0.2510695435618535
# INFO :      		round 96: 0.2502245694494095
# INFO :      		round 97: 0.25032232252482217
# INFO :      		round 98: 0.24706374300411715
# INFO :      		round 99: 0.2464369037292731
# INFO :      		round 100: 0.24647052254016028
# INFO :      	History (metrics, centralized):
# INFO :      	{'test_accuracy': [(0, 0.0646),
# INFO :      	                   (1, 0.7377),
# INFO :      	                   (2, 0.7665),
# INFO :      	                   (3, 0.7905),
# INFO :      	                   (4, 0.8105),
# INFO :      	                   (5, 0.8197),
# INFO :      	                   (6, 0.8339),
# INFO :      	                   (7, 0.8367),
# INFO :      	                   (8, 0.8456),
# INFO :      	                   (9, 0.8508),
# INFO :      	                   (10, 0.8503),
# INFO :      	                   (11, 0.856),
# INFO :      	                   (12, 0.8601),
# INFO :      	                   (13, 0.8632),
# INFO :      	                   (14, 0.8641),
# INFO :      	                   (15, 0.8679),
# INFO :      	                   (16, 0.8698),
# INFO :      	                   (17, 0.8693),
# INFO :      	                   (18, 0.8695),
# INFO :      	                   (19, 0.8751),
# INFO :      	                   (20, 0.8741),
# INFO :      	                   (21, 0.8764),
# INFO :      	                   (22, 0.8754),
# INFO :      	                   (23, 0.8785),
# INFO :      	                   (24, 0.8772),
# INFO :      	                   (25, 0.8792),
# INFO :      	                   (26, 0.8801),
# INFO :      	                   (27, 0.882),
# INFO :      	                   (28, 0.8831),
# INFO :      	                   (29, 0.8832),
# INFO :      	                   (30, 0.8855),
# INFO :      	                   (31, 0.8863),
# INFO :      	                   (32, 0.8873),
# INFO :      	                   (33, 0.8854),
# INFO :      	                   (34, 0.8888),
# INFO :      	                   (35, 0.8879),
# INFO :      	                   (36, 0.892),
# INFO :      	                   (37, 0.8923),
# INFO :      	                   (38, 0.8925),
# INFO :      	                   (39, 0.8935),
# INFO :      	                   (40, 0.8928),
# INFO :      	                   (41, 0.891),
# INFO :      	                   (42, 0.8926),
# INFO :      	                   (43, 0.8923),
# INFO :      	                   (44, 0.8928),
# INFO :      	                   (45, 0.8924),
# INFO :      	                   (46, 0.8942),
# INFO :      	                   (47, 0.8979),
# INFO :      	                   (48, 0.8974),
# INFO :      	                   (49, 0.8975),
# INFO :      	                   (50, 0.8964),
# INFO :      	                   (51, 0.897),
# INFO :      	                   (52, 0.8975),
# INFO :      	                   (53, 0.898),
# INFO :      	                   (54, 0.8978),
# INFO :      	                   (55, 0.8967),
# INFO :      	                   (56, 0.8995),
# INFO :      	                   (57, 0.9005),
# INFO :      	                   (58, 0.9004),
# INFO :      	                   (59, 0.9025),
# INFO :      	                   (60, 0.9002),
# INFO :      	                   (61, 0.9017),
# INFO :      	                   (62, 0.9014),
# INFO :      	                   (63, 0.9011),
# INFO :      	                   (64, 0.9031),
# INFO :      	                   (65, 0.9032),
# INFO :      	                   (66, 0.9032),
# INFO :      	                   (67, 0.9026),
# INFO :      	                   (68, 0.9035),
# INFO :      	                   (69, 0.9063),
# INFO :      	                   (70, 0.9038),
# INFO :      	                   (71, 0.9044),
# INFO :      	                   (72, 0.9037),
# INFO :      	                   (73, 0.9053),
# INFO :      	                   (74, 0.9057),
# INFO :      	                   (75, 0.9048),
# INFO :      	                   (76, 0.9051),
# INFO :      	                   (77, 0.9068),
# INFO :      	                   (78, 0.9065),
# INFO :      	                   (79, 0.9064),
# INFO :      	                   (80, 0.9082),
# INFO :      	                   (81, 0.9067),
# INFO :      	                   (82, 0.9082),
# INFO :      	                   (83, 0.9072),
# INFO :      	                   (84, 0.9076),
# INFO :      	                   (85, 0.9081),
# INFO :      	                   (86, 0.9102),
# INFO :      	                   (87, 0.9092),
# INFO :      	                   (88, 0.9078),
# INFO :      	                   (89, 0.9089),
# INFO :      	                   (90, 0.9084),
# INFO :      	                   (91, 0.9091),
# INFO :      	                   (92, 0.9104),
# INFO :      	                   (93, 0.91),
# INFO :      	                   (94, 0.911),
# INFO :      	                   (95, 0.9117),
# INFO :      	                   (96, 0.9088),
# INFO :      	                   (97, 0.9113),
# INFO :      	                   (98, 0.912),
# INFO :      	                   (99, 0.9116),
# INFO :      	                   (100, 0.9128)]}
# INFO :

# %% [markdown]
# SCAFFOLD WITH FASHIONMNIST- 1 LOCAL EPOCH WITH 100 ROUNDS

# %%
import flwr as fl
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
from torch.utils.data import DataLoader, random_split, Subset
import numpy as np
import matplotlib.pyplot as plt
import copy


# Model

class SimpleCNN(nn.Module):
    def __init__(self):
        super(SimpleCNN, self).__init__()
        self.network = nn.Sequential(
            nn.Conv2d(1, 32, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(2, 2),
            nn.Conv2d(32, 64, kernel_size=3, padding=1),
            nn.ReLU(),
            nn.MaxPool2d(2, 2),
            nn.Flatten(),
            nn.Linear(64 * 7 * 7, 128),
            nn.ReLU(),
            nn.Linear(128, 10) 
        )

    def forward(self, x):
        return self.network(x)

DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")


# Load FashionMNIST

transform = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize((0.5,), (0.5,))
])

trainset = torchvision.datasets.FashionMNIST(root="./data", train=True, download=True, transform=transform)
testset = torchvision.datasets.FashionMNIST(root="./data", train=False, download=True, transform=transform)
testloader = DataLoader(testset, batch_size=32)


# IID DataLoader

def get_client_dataloader(client_id, num_clients, batch_size=32):
    total_size = len(trainset)
    split_size = total_size // num_clients
    indices = list(range(total_size))
    np.random.seed(42)
    np.random.shuffle(indices)

    client_indices = indices[client_id * split_size: (client_id + 1) * split_size]
    subset = Subset(trainset, client_indices)

    train_len = int(0.8 * len(subset))
    val_len = len(subset) - train_len
    train_data, val_data = random_split(subset, [train_len, val_len])

    return (
        DataLoader(train_data, batch_size=batch_size, shuffle=True),
        DataLoader(val_data, batch_size=batch_size, shuffle=False),
    )


# Flower Client with SCAFFOLD

class ScaffoldClient(fl.client.NumPyClient):
    def __init__(self, cid, c_global, c_local_dict):
        self.cid = int(cid)
        self.model = SimpleCNN().to(DEVICE)
        self.trainloader, self.valloader = get_client_dataloader(self.cid, num_clients=5)
        self.c_global = c_global
        self.c_local = c_local_dict[self.cid]

    def get_parameters(self, config):
        return [val.cpu().numpy() for _, val in self.model.state_dict().items()]

    def set_parameters(self, parameters):
        state_dict = self.model.state_dict()
        for k, v in zip(state_dict.keys(), parameters):
            state_dict[k] = torch.tensor(v)
        self.model.load_state_dict(state_dict)

    def fit(self, parameters, config):
        self.set_parameters(parameters)
        self.model.train()

        optimizer = optim.SGD(self.model.parameters(), lr=0.01)
        criterion = nn.CrossEntropyLoss()
        local_epochs = 1

        old_weights = copy.deepcopy(self.model.state_dict())

        for _ in range(local_epochs):
            for x, y in self.trainloader:
                x, y = x.to(DEVICE), y.to(DEVICE)
                optimizer.zero_grad()
                output = self.model(x)
                loss = criterion(output, y)
                loss.backward()

                for name, param in self.model.named_parameters():
                    if param.grad is not None:
                        param.grad += self.c_global[name].to(DEVICE) - self.c_local[name].to(DEVICE)

                optimizer.step()

        new_weights = self.model.state_dict()
        delta_weights = {k: new_weights[k] - old_weights[k] for k in new_weights}
        for k in self.c_local:
            self.c_local[k] = self.c_local[k] - self.c_global[k] + delta_weights[k] / (local_epochs * 0.01)

        return self.get_parameters({}), len(self.trainloader.dataset), {}

    def evaluate(self, parameters, config):
        self.set_parameters(parameters)
        self.model.eval()
        correct, total, loss = 0, 0, 0
        criterion = nn.CrossEntropyLoss()

        with torch.no_grad():
            for x, y in self.valloader:
                x, y = x.to(DEVICE), y.to(DEVICE)
                outputs = self.model(x)
                loss += criterion(outputs, y).item()
                _, predicted = torch.max(outputs.data, 1)
                total += y.size(0)
                correct += (predicted == y).sum().item()

        return loss / len(self.valloader), len(self.valloader.dataset), {"accuracy": correct / total}


# Control Variates

c_global = {k: torch.zeros_like(v) for k, v in SimpleCNN().state_dict().items()}
c_local_dict = {i: {k: torch.zeros_like(v) for k, v in SimpleCNN().state_dict().items()} for i in range(5)}


# Client Factory

def client_fn(cid: str):
    return ScaffoldClient(cid, c_global, c_local_dict).to_client()


# Evaluation Function

test_losses, test_accuracies = [], []

def evaluate_fn(server_round, parameters, config):
    model = SimpleCNN().to(DEVICE)
    state_dict = model.state_dict()
    for k, v in zip(state_dict.keys(), parameters):
        state_dict[k] = torch.tensor(v)
    model.load_state_dict(state_dict)
    model.eval()

    criterion = nn.CrossEntropyLoss()
    correct, total, loss = 0, 0, 0

    with torch.no_grad():
        for x, y in testloader:
            x, y = x.to(DEVICE), y.to(DEVICE)
            output = model(x)
            loss += criterion(output, y).item()
            _, predicted = torch.max(output.data, 1)
            total += y.size(0)
            correct += (predicted == y).sum().item()

    avg_loss = loss / len(testloader)
    accuracy = correct / total
    test_losses.append(avg_loss)
    test_accuracies.append(accuracy)
    print(f"[Round {server_round}] Test Loss: {avg_loss:.4f}, Accuracy: {accuracy:.4f}")
    return avg_loss, {"test_accuracy": accuracy}


# Simulation

if __name__ == "__main__":
    initial_model = SimpleCNN()
    initial_parameters = fl.common.ndarrays_to_parameters(
        [val.cpu().numpy() for _, val in initial_model.state_dict().items()]
    )

    fl.simulation.start_simulation(
        client_fn=client_fn,
        num_clients=5,
        config=fl.server.ServerConfig(num_rounds=100),
        strategy=fl.server.strategy.FedAvg(
            fraction_fit=1.0,
            fraction_evaluate=1.0,
            min_fit_clients=5,
            min_evaluate_clients=5,
            min_available_clients=5,
            evaluate_fn=evaluate_fn,
            initial_parameters=initial_parameters,
        ),
    )

    # Save metrics
    np.save("scaffold_fashionmnist_test_accuracies.npy", np.array(test_accuracies))
    np.save("scaffold_fashionmnist_test_losses.npy", np.array(test_losses))

    # Plot
    rounds = list(range(1, len(test_losses) + 1))
    fig, ax1 = plt.subplots(figsize=(10, 5))

    ax1.set_xlabel("Round")
    ax1.set_ylabel("Test Loss", color="red")
    ax1.plot(rounds, test_losses, color="red", marker="o")
    ax1.tick_params(axis="y", labelcolor="red")

    ax2 = ax1.twinx()
    ax2.set_ylabel("Test Accuracy", color="blue")
    ax2.plot(rounds, test_accuracies, color="blue", marker="o")
    ax2.tick_params(axis="y", labelcolor="blue")

    plt.title("SCAFFOLD on FashionMNIST")
    fig.tight_layout()
    plt.savefig("scaffold_fashionmnist_loss_accuracy.png")
    plt.show()
# Out:
# 2025-08-06 00:28:54,521	INFO util.py:154 -- Outdated packages:
#   ipywidgets==7.8.1 found, needs ipywidgets>=8
# Run `pip install -U ipywidgets`, then restart the notebook server for rich notebook output.
# WARNING :   DEPRECATED FEATURE: flwr.simulation.start_simulation() is deprecated.
# 	Instead, use the `flwr run` CLI command to start a local simulation in your Flower app, as shown for example below:
#
# 		$ flwr new  # Create a new Flower app from a template
#
# 		$ flwr run  # Run the Flower app in Simulation Mode
#
# 	Using `start_simulation()` is deprecated.
#
#             This is a deprecated feature. It will be removed
#             entirely in future versions of Flower.
#
# INFO :      Starting Flower simulation, config: num_rounds=100, no round_timeout
# 2025-08-06 00:28:58,605	INFO worker.py:1771 -- Started a local Ray instance.
# INFO :      Flower VCE: Ray initialized with resources: {'node:__internal_head__': 1.0, 'node:127.0.0.1': 1.0, 'CPU': 8.0, 'object_store_memory': 1620276019.0, 'memory': 3240552039.0}
# INFO :      Optimize your simulation with Flower VCE: https://flower.ai/docs/framework/how-to-run-simulations.html
# INFO :      No `client_resources` specified. Using minimal resources for clients.
# INFO :      Flower VCE: Resources for each Virtual Client: {'num_cpus': 1, 'num_gpus': 0.0}
# INFO :      Flower VCE: Creating VirtualClientEngineActorPool with 8 actors
# INFO :      [INIT]
# INFO :      Using initial global parameters provided by strategy
# INFO :      Starting evaluation of initial global parameters
# INFO :      initial parameters (loss, other metrics): 2.305992204922076, {'test_accuracy': 0.1003}
# INFO :
# INFO :      [ROUND 1]
# INFO :      configure_fit: strategy sampled 5 clients (out of 5)
# [Round 0] Test Loss: 2.3060, Accuracy: 0.1003
# (ClientAppActor pid=64759) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context`
# (ClientAppActor pid=64759)
# (ClientAppActor pid=64759)             This is a deprecated feature. It will be removed
# (ClientAppActor pid=64759)             entirely in future versions of Flower.
# (ClientAppActor pid=64759)
# (ClientAppActor pid=64755)
# (ClientAppActor pid=64755)
# (ClientAppActor pid=64758)
# (ClientAppActor pid=64758)
# (ClientAppActor pid=64756)
# (ClientAppActor pid=64756)
# (ClientAppActor pid=64757)
# (ClientAppActor pid=64757)
# INFO :      aggregate_fit: received 5 results and 0 failures
# WARNING :   No fit_metrics_aggregation_fn provided
# INFO :      fit progress: (1, 0.8265918066707282, {'test_accuracy': 0.7104}, 22.615714917425066)
# INFO :      configure_evaluate: strategy sampled 5 clients (out of 5)
# [Round 1] Test Loss: 0.8266, Accuracy: 0.7104
# (ClientAppActor pid=64756)
# (ClientAppActor pid=64756)
# (ClientAppActor pid=64756) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 5x across cluster] (Ray deduplicates logs by default. Set RAY_DEDUP_LOGS=0 to disable log deduplication, or see https://docs.ray.io/en/master/ray-observability/user-guides/configure-logging.html#log-deduplication for more options.)
# (ClientAppActor pid=64756)             This is a deprecated feature. It will be removed [repeated 5x across cluster]
# (ClientAppActor pid=64756)             entirely in future versions of Flower. [repeated 5x across cluster]
# (ClientAppActor pid=64755)
# (ClientAppActor pid=64755)
# (ClientAppActor pid=64758)
# (ClientAppActor pid=64758)
# (ClientAppActor pid=64757)
# (ClientAppActor pid=64757)
# (ClientAppActor pid=64759)
# (ClientAppActor pid=64759)
# INFO :      aggregate_evaluate: received 5 results and 0 failures
# WARNING :   No evaluate_metrics_aggregation_fn provided
# INFO :
# INFO :      [ROUND 2]
# INFO :      configure_fit: strategy sampled 5 clients (out of 5)
# (ClientAppActor pid=64759)
# (ClientAppActor pid=64759)
# (ClientAppActor pid=64758)
# (ClientAppActor pid=64758)
# (ClientAppActor pid=64757)
# (ClientAppActor pid=64757)
# (ClientAppActor pid=64756)
# (ClientAppActor pid=64756)
# (ClientAppActor pid=64755)
# (ClientAppActor pid=64755)
# INFO :      aggregate_fit: received 5 results and 0 failures
# INFO :      fit progress: (2, 0.6592659297080847, {'test_accuracy': 0.7461}, 35.22562400018796)
# INFO :      configure_evaluate: strategy sampled 5 clients (out of 5)
# [Round 2] Test Loss: 0.6593, Accuracy: 0.7461
# (ClientAppActor pid=64756)
# (ClientAppActor pid=64756)
# (ClientAppActor pid=64756) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 10x across cluster]
# (ClientAppActor pid=64756)             This is a deprecated feature. It will be removed [repeated 10x across cluster]
# (ClientAppActor pid=64756)             entirely in future versions of Flower. [repeated 10x across cluster]
# (ClientAppActor pid=64755)
# (ClientAppActor pid=64755)
# (ClientAppActor pid=64757)
# (ClientAppActor pid=64757)
# (ClientAppActor pid=64759)
# (ClientAppActor pid=64759)
# (ClientAppActor pid=64758)
# (ClientAppActor pid=64758)
# INFO :      aggregate_evaluate: received 5 results and 0 failures
# INFO :
# INFO :      [ROUND 3]
# INFO :      configure_fit: strategy sampled 5 clients (out of 5)
# (ClientAppActor pid=64758)
# (ClientAppActor pid=64758)
# (ClientAppActor pid=64759)
# (ClientAppActor pid=64759)
# (ClientAppActor pid=64755)
# (ClientAppActor pid=64755)
# (ClientAppActor pid=64757)
# (ClientAppActor pid=64757)
# (ClientAppActor pid=64756)
# (ClientAppActor pid=64756)
# INFO :      aggregate_fit: received 5 results and 0 failures
# INFO :      fit progress: (3, 0.5779388207025802, {'test_accuracy': 0.777}, 46.567030750215054)
# INFO :      configure_evaluate: strategy sampled 5 clients (out of 5)
# [Round 3] Test Loss: 0.5779, Accuracy: 0.7770
# (ClientAppActor pid=64755)
# (ClientAppActor pid=64755)
# (ClientAppActor pid=64755) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 10x across cluster]
# (ClientAppActor pid=64755)             This is a deprecated feature. It will be removed [repeated 10x across cluster]
# (ClientAppActor pid=64755)             entirely in future versions of Flower. [repeated 10x across cluster]
# (ClientAppActor pid=64757)
# (ClientAppActor pid=64757)
# (ClientAppActor pid=64756)
# (ClientAppActor pid=64756)
# (ClientAppActor pid=64758)
# (ClientAppActor pid=64758)
# (ClientAppActor pid=64759)
# (ClientAppActor pid=64759)
# INFO :      aggregate_evaluate: received 5 results and 0 failures
# INFO :
# INFO :      [ROUND 4]
# INFO :      configure_fit: strategy sampled 5 clients (out of 5)
# (ClientAppActor pid=64758)
# (ClientAppActor pid=64758)
# (ClientAppActor pid=64759)
# (ClientAppActor pid=64759)
# (ClientAppActor pid=64756)
# (ClientAppActor pid=64756)
# (ClientAppActor pid=64755)
# (ClientAppActor pid=64755)
# (ClientAppActor pid=64757)
# (ClientAppActor pid=64757)
# INFO :      aggregate_fit: received 5 results and 0 failures
# INFO :      fit progress: (4, 0.5329283137862294, {'test_accuracy': 0.8017}, 59.81787829240784)
# INFO :      configure_evaluate: strategy sampled 5 clients (out of 5)
# [Round 4] Test Loss: 0.5329, Accuracy: 0.8017
# (ClientAppActor pid=64757)
# (ClientAppActor pid=64757)
# (ClientAppActor pid=64757) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 10x across cluster]
# (ClientAppActor pid=64757)             This is a deprecated feature. It will be removed [repeated 10x across cluster]
# (ClientAppActor pid=64757)             entirely in future versions of Flower. [repeated 10x across cluster]
# (ClientAppActor pid=64755)
# (ClientAppActor pid=64755)
# (ClientAppActor pid=64758)
# (ClientAppActor pid=64758)
# (ClientAppActor pid=64756)
# (ClientAppActor pid=64756)
# (ClientAppActor pid=64759)
# (ClientAppActor pid=64759)
# INFO :      aggregate_evaluate: received 5 results and 0 failures
# INFO :
# INFO :      [ROUND 5]
# INFO :      configure_fit: strategy sampled 5 clients (out of 5)
# (ClientAppActor pid=64756)
# (ClientAppActor pid=64756)
# (ClientAppActor pid=64759)
# (ClientAppActor pid=64759)
# (ClientAppActor pid=64758)
# (ClientAppActor pid=64758)
# (ClientAppActor pid=64757)
# (ClientAppActor pid=64757)
# (ClientAppActor pid=64755)
# (ClientAppActor pid=64755)
# INFO :      aggregate_fit: received 5 results and 0 failures
# INFO :      fit progress: (5, 0.5128635715562314, {'test_accuracy': 0.8114}, 73.08975937496871)
# INFO :      configure_evaluate: strategy sampled 5 clients (out of 5)
# [Round 5] Test Loss: 0.5129, Accuracy: 0.8114
# (ClientAppActor pid=64755)
# (ClientAppActor pid=64755)
# (ClientAppActor pid=64755) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 10x across cluster]
# (ClientAppActor pid=64755)             This is a deprecated feature. It will be removed [repeated 10x across cluster]
# (ClientAppActor pid=64755)             entirely in future versions of Flower. [repeated 10x across cluster]
# (ClientAppActor pid=64757)
# (ClientAppActor pid=64757)
# (ClientAppActor pid=64758)
# (ClientAppActor pid=64758)
# (ClientAppActor pid=64756)
# (ClientAppActor pid=64756)
# (ClientAppActor pid=64759)
# (ClientAppActor pid=64759)
# INFO :      aggregate_evaluate: received 5 results and 0 failures
# INFO :
# INFO :      [ROUND 6]
# INFO :      configure_fit: strategy sampled 5 clients (out of 5)
# (ClientAppActor pid=64756)
# (ClientAppActor pid=64756)
# (ClientAppActor pid=64759)
# (ClientAppActor pid=64759)
# (ClientAppActor pid=64758)
# (ClientAppActor pid=64758)
# (ClientAppActor pid=64757)
# (ClientAppActor pid=64757)
# (ClientAppActor pid=64755)
# (ClientAppActor pid=64755)
# INFO :      aggregate_fit: received 5 results and 0 failures
# INFO :      fit progress: (6, 0.48316296992210533, {'test_accuracy': 0.8214}, 85.77536291722208)
# INFO :      configure_evaluate: strategy sampled 5 clients (out of 5)
# [Round 6] Test Loss: 0.4832, Accuracy: 0.8214
# (ClientAppActor pid=64755)
# (ClientAppActor pid=64755)
# (ClientAppActor pid=64755) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 10x across cluster]
# (ClientAppActor pid=64755)             This is a deprecated feature. It will be removed [repeated 10x across cluster]
# (ClientAppActor pid=64755)             entirely in future versions of Flower. [repeated 10x across cluster]
# (ClientAppActor pid=64758)
# (ClientAppActor pid=64758)
# (ClientAppActor pid=64757)
# (ClientAppActor pid=64757)
# (ClientAppActor pid=64759)
# (ClientAppActor pid=64759)
# (ClientAppActor pid=64756)
# (ClientAppActor pid=64756)
# INFO :      aggregate_evaluate: received 5 results and 0 failures
# INFO :
# INFO :      [ROUND 7]
# INFO :      configure_fit: strategy sampled 5 clients (out of 5)
# (ClientAppActor pid=64756)
# (ClientAppActor pid=64756)
# (ClientAppActor pid=64758)
# (ClientAppActor pid=64758)
# (ClientAppActor pid=64757)
# (ClientAppActor pid=64757)
# (ClientAppActor pid=64755)
# (ClientAppActor pid=64755)
# (ClientAppActor pid=64759)
# (ClientAppActor pid=64759)
# INFO :      aggregate_fit: received 5 results and 0 failures
# INFO :      fit progress: (7, 0.46302113803430867, {'test_accuracy': 0.8325}, 99.13905954221264)
# INFO :      configure_evaluate: strategy sampled 5 clients (out of 5)
# [Round 7] Test Loss: 0.4630, Accuracy: 0.8325
# (ClientAppActor pid=64755)
# (ClientAppActor pid=64755)
# (ClientAppActor pid=64755) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 10x across cluster]
# (ClientAppActor pid=64755)             This is a deprecated feature. It will be removed [repeated 10x across cluster]
# (ClientAppActor pid=64755)             entirely in future versions of Flower. [repeated 10x across cluster]
# (ClientAppActor pid=64759)
# (ClientAppActor pid=64759)
# (ClientAppActor pid=64757)
# (ClientAppActor pid=64757)
# (ClientAppActor pid=64756)
# (ClientAppActor pid=64756)
# (ClientAppActor pid=64758)
# (ClientAppActor pid=64758)
# INFO :      aggregate_evaluate: received 5 results and 0 failures
# INFO :
# INFO :      [ROUND 8]
# INFO :      configure_fit: strategy sampled 5 clients (out of 5)
# (ClientAppActor pid=64758)
# (ClientAppActor pid=64758)
# (ClientAppActor pid=64756)
# (ClientAppActor pid=64756)
# (ClientAppActor pid=64757)
# (ClientAppActor pid=64757)
# (ClientAppActor pid=64759)
# (ClientAppActor pid=64759)
# (ClientAppActor pid=64755)
# (ClientAppActor pid=64755)
# INFO :      aggregate_fit: received 5 results and 0 failures
# INFO :      fit progress: (8, 0.4421943262362252, {'test_accuracy': 0.841}, 112.67393845831975)
# INFO :      configure_evaluate: strategy sampled 5 clients (out of 5)
# [Round 8] Test Loss: 0.4422, Accuracy: 0.8410
# (ClientAppActor pid=64755)
# (ClientAppActor pid=64755)
# (ClientAppActor pid=64755) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 10x across cluster]
# (ClientAppActor pid=64755)             This is a deprecated feature. It will be removed [repeated 10x across cluster]
# (ClientAppActor pid=64755)             entirely in future versions of Flower. [repeated 10x across cluster]
# (ClientAppActor pid=64759)
# (ClientAppActor pid=64759)
# (ClientAppActor pid=64757)
# (ClientAppActor pid=64757)
# (ClientAppActor pid=64756)
# (ClientAppActor pid=64756)
# (ClientAppActor pid=64758)
# (ClientAppActor pid=64758)
# INFO :      aggregate_evaluate: received 5 results and 0 failures
# INFO :
# INFO :      [ROUND 9]
# INFO :      configure_fit: strategy sampled 5 clients (out of 5)
# (ClientAppActor pid=64758)
# (ClientAppActor pid=64758)
# (ClientAppActor pid=64756)
# (ClientAppActor pid=64756)
# (ClientAppActor pid=64757)
# (ClientAppActor pid=64757)
# (ClientAppActor pid=64759)
# (ClientAppActor pid=64759)
# (ClientAppActor pid=64755)
# (ClientAppActor pid=64755)
# INFO :      aggregate_fit: received 5 results and 0 failures
# INFO :      fit progress: (9, 0.42702485042543836, {'test_accuracy': 0.8478}, 133.48073937511072)
# INFO :      configure_evaluate: strategy sampled 5 clients (out of 5)
# [Round 9] Test Loss: 0.4270, Accuracy: 0.8478
# (ClientAppActor pid=64755)
# (ClientAppActor pid=64755)
# (ClientAppActor pid=64755) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 10x across cluster]
# (ClientAppActor pid=64755)             This is a deprecated feature. It will be removed [repeated 10x across cluster]
# (ClientAppActor pid=64755)             entirely in future versions of Flower. [repeated 10x across cluster]
# (ClientAppActor pid=64759)
# (ClientAppActor pid=64759)
# (ClientAppActor pid=64757)
# (ClientAppActor pid=64757)
# (ClientAppActor pid=64756)
# (ClientAppActor pid=64756)
# (ClientAppActor pid=64758)
# (ClientAppActor pid=64758)
# INFO :      aggregate_evaluate: received 5 results and 0 failures
# INFO :
# INFO :      [ROUND 10]
# INFO :      configure_fit: strategy sampled 5 clients (out of 5)
# (ClientAppActor pid=64758)
# (ClientAppActor pid=64758)
# (ClientAppActor pid=64756)
# (ClientAppActor pid=64756)
# (ClientAppActor pid=64757)
# (ClientAppActor pid=64757)
# (ClientAppActor pid=64759)
# (ClientAppActor pid=64759)
# (ClientAppActor pid=64755)
# (ClientAppActor pid=64755)
# (ClientAppActor pid=64755) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 9x across cluster]
# (ClientAppActor pid=64755)             This is a deprecated feature. It will be removed [repeated 9x across cluster]
# (ClientAppActor pid=64755)             entirely in future versions of Flower. [repeated 9x across cluster]
# INFO :      aggregate_fit: received 5 results and 0 failures
# INFO :      fit progress: (10, 0.4178100599410435, {'test_accuracy': 0.8503}, 151.17255012504756)
# INFO :      configure_evaluate: strategy sampled 5 clients (out of 5)
# [Round 10] Test Loss: 0.4178, Accuracy: 0.8503
# (ClientAppActor pid=64755)
# (ClientAppActor pid=64755)
# (ClientAppActor pid=64755) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context`
# (ClientAppActor pid=64755)             This is a deprecated feature. It will be removed
# (ClientAppActor pid=64755)             entirely in future versions of Flower.
# (ClientAppActor pid=64759) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context`
# (ClientAppActor pid=64759)
# (ClientAppActor pid=64759)             This is a deprecated feature. It will be removed
# (ClientAppActor pid=64759)             entirely in future versions of Flower.
# (ClientAppActor pid=64759)
# (ClientAppActor pid=64757)
# (ClientAppActor pid=64757)
# (ClientAppActor pid=64756)
# (ClientAppActor pid=64756)
# (ClientAppActor pid=64758)
# (ClientAppActor pid=64758)
# INFO :      aggregate_evaluate: received 5 results and 0 failures
# INFO :
# INFO :      [ROUND 11]
# INFO :      configure_fit: strategy sampled 5 clients (out of 5)
# (ClientAppActor pid=64758)
# (ClientAppActor pid=64758)
# (ClientAppActor pid=64756)
# (ClientAppActor pid=64756)
# (ClientAppActor pid=64757)
# (ClientAppActor pid=64757)
# (ClientAppActor pid=64755)
# (ClientAppActor pid=64755)
# (ClientAppActor pid=64759)
# (ClientAppActor pid=64759)
# INFO :      aggregate_fit: received 5 results and 0 failures
# INFO :      fit progress: (11, 0.4085696227491473, {'test_accuracy': 0.8516}, 165.36941183311865)
# INFO :      configure_evaluate: strategy sampled 5 clients (out of 5)
# [Round 11] Test Loss: 0.4086, Accuracy: 0.8516
# (ClientAppActor pid=64757)
# (ClientAppActor pid=64757)
# (ClientAppActor pid=64757) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 9x across cluster]
# (ClientAppActor pid=64757)             This is a deprecated feature. It will be removed [repeated 9x across cluster]
# (ClientAppActor pid=64757)             entirely in future versions of Flower. [repeated 9x across cluster]
# (ClientAppActor pid=64755)
# (ClientAppActor pid=64755)
# (ClientAppActor pid=64759)
# (ClientAppActor pid=64759)
# (ClientAppActor pid=64756)
# (ClientAppActor pid=64756)
# (ClientAppActor pid=64758)
# (ClientAppActor pid=64758)
# INFO :      aggregate_evaluate: received 5 results and 0 failures
# INFO :
# INFO :      [ROUND 12]
# INFO :      configure_fit: strategy sampled 5 clients (out of 5)
# (ClientAppActor pid=64758)
# (ClientAppActor pid=64758)
# (ClientAppActor pid=64756)
# (ClientAppActor pid=64756)
# (ClientAppActor pid=64759)
# (ClientAppActor pid=64759)
# (ClientAppActor pid=64755)
# (ClientAppActor pid=64755)
# (ClientAppActor pid=64757)
# (ClientAppActor pid=64757)
# INFO :      aggregate_fit: received 5 results and 0 failures
# INFO :      fit progress: (12, 0.39446587053636395, {'test_accuracy': 0.8575}, 177.37628970807418)
# INFO :      configure_evaluate: strategy sampled 5 clients (out of 5)
# [Round 12] Test Loss: 0.3945, Accuracy: 0.8575
# (ClientAppActor pid=64755)
# (ClientAppActor pid=64755)
# (ClientAppActor pid=64755) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 10x across cluster]
# (ClientAppActor pid=64755)             This is a deprecated feature. It will be removed [repeated 10x across cluster]
# (ClientAppActor pid=64755)             entirely in future versions of Flower. [repeated 10x across cluster]
# (ClientAppActor pid=64758)
# (ClientAppActor pid=64758)
# (ClientAppActor pid=64757)
# (ClientAppActor pid=64757)
# (ClientAppActor pid=64759)
# (ClientAppActor pid=64759)
# (ClientAppActor pid=64756)
# (ClientAppActor pid=64756)
# INFO :      aggregate_evaluate: received 5 results and 0 failures
# INFO :
# INFO :      [ROUND 13]
# INFO :      configure_fit: strategy sampled 5 clients (out of 5)
# (ClientAppActor pid=64756)
# (ClientAppActor pid=64756)
# (ClientAppActor pid=64757)
# (ClientAppActor pid=64757)
# (ClientAppActor pid=64759)
# (ClientAppActor pid=64759)
# (ClientAppActor pid=64758)
# (ClientAppActor pid=64758)
# (ClientAppActor pid=64755)
# (ClientAppActor pid=64755)
# INFO :      aggregate_fit: received 5 results and 0 failures
# INFO :      fit progress: (13, 0.3885107981844451, {'test_accuracy': 0.859}, 188.7235227082856)
# INFO :      configure_evaluate: strategy sampled 5 clients (out of 5)
# [Round 13] Test Loss: 0.3885, Accuracy: 0.8590
# (ClientAppActor pid=64758)
# (ClientAppActor pid=64758)
# (ClientAppActor pid=64758) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 10x across cluster]
# (ClientAppActor pid=64758)             This is a deprecated feature. It will be removed [repeated 10x across cluster]
# (ClientAppActor pid=64758)             entirely in future versions of Flower. [repeated 10x across cluster]
# (ClientAppActor pid=64755)
# (ClientAppActor pid=64755)
# (ClientAppActor pid=64756)
# (ClientAppActor pid=64756)
# (ClientAppActor pid=64757)
# (ClientAppActor pid=64757)
# (ClientAppActor pid=64759)
# (ClientAppActor pid=64759)
# INFO :      aggregate_evaluate: received 5 results and 0 failures
# INFO :
# INFO :      [ROUND 14]
# INFO :      configure_fit: strategy sampled 5 clients (out of 5)
# (ClientAppActor pid=64759)
# (ClientAppActor pid=64759)
# (ClientAppActor pid=64758)
# (ClientAppActor pid=64758)
# (ClientAppActor pid=64756)
# (ClientAppActor pid=64756)
# (ClientAppActor pid=64757)
# (ClientAppActor pid=64757)
# (ClientAppActor pid=64755)
# (ClientAppActor pid=64755)
# INFO :      aggregate_fit: received 5 results and 0 failures
# INFO :      fit progress: (14, 0.39187687504501006, {'test_accuracy': 0.8583}, 200.4718658332713)
# INFO :      configure_evaluate: strategy sampled 5 clients (out of 5)
# [Round 14] Test Loss: 0.3919, Accuracy: 0.8583
# (ClientAppActor pid=64755)
# (ClientAppActor pid=64755)
# (ClientAppActor pid=64755) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 10x across cluster]
# (ClientAppActor pid=64755)             This is a deprecated feature. It will be removed [repeated 10x across cluster]
# (ClientAppActor pid=64755)             entirely in future versions of Flower. [repeated 10x across cluster]
# (ClientAppActor pid=64757)
# (ClientAppActor pid=64757)
# (ClientAppActor pid=64756)
# (ClientAppActor pid=64756)
# (ClientAppActor pid=64759)
# (ClientAppActor pid=64759)
# (ClientAppActor pid=64758)
# (ClientAppActor pid=64758)
# INFO :      aggregate_evaluate: received 5 results and 0 failures
# INFO :
# INFO :      [ROUND 15]
# INFO :      configure_fit: strategy sampled 5 clients (out of 5)
# (ClientAppActor pid=64758)
# (ClientAppActor pid=64758)
# (ClientAppActor pid=64759)
# (ClientAppActor pid=64759)
# (ClientAppActor pid=64756)
# (ClientAppActor pid=64756)
# (ClientAppActor pid=64757)
# (ClientAppActor pid=64757)
# (ClientAppActor pid=64755)
# (ClientAppActor pid=64755)
# INFO :      aggregate_fit: received 5 results and 0 failures
# INFO :      fit progress: (15, 0.37576487531867653, {'test_accuracy': 0.8639}, 214.36685766698793)
# INFO :      configure_evaluate: strategy sampled 5 clients (out of 5)
# [Round 15] Test Loss: 0.3758, Accuracy: 0.8639
# (ClientAppActor pid=64755)
# (ClientAppActor pid=64755)
# (ClientAppActor pid=64755) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 10x across cluster]
# (ClientAppActor pid=64755)             This is a deprecated feature. It will be removed [repeated 10x across cluster]
# (ClientAppActor pid=64755)             entirely in future versions of Flower. [repeated 10x across cluster]
# (ClientAppActor pid=64757)
# (ClientAppActor pid=64757)
# (ClientAppActor pid=64756)
# (ClientAppActor pid=64756)
# (ClientAppActor pid=64759)
# (ClientAppActor pid=64759)
# (ClientAppActor pid=64758)
# (ClientAppActor pid=64758)
# INFO :      aggregate_evaluate: received 5 results and 0 failures
# INFO :
# INFO :      [ROUND 16]
# INFO :      configure_fit: strategy sampled 5 clients (out of 5)
# (ClientAppActor pid=64758)
# (ClientAppActor pid=64758)
# (ClientAppActor pid=64759)
# (ClientAppActor pid=64759)
# (ClientAppActor pid=64756)
# (ClientAppActor pid=64756)
# (ClientAppActor pid=64757)
# (ClientAppActor pid=64757)
# (ClientAppActor pid=64755)
# (ClientAppActor pid=64755)
# INFO :      aggregate_fit: received 5 results and 0 failures
# INFO :      fit progress: (16, 0.3712343864452344, {'test_accuracy': 0.8655}, 229.0010291673243)
# INFO :      configure_evaluate: strategy sampled 5 clients (out of 5)
# [Round 16] Test Loss: 0.3712, Accuracy: 0.8655
# (ClientAppActor pid=64755)
# (ClientAppActor pid=64755)
# (ClientAppActor pid=64755) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 10x across cluster]
# (ClientAppActor pid=64755)             This is a deprecated feature. It will be removed [repeated 10x across cluster]
# (ClientAppActor pid=64755)             entirely in future versions of Flower. [repeated 10x across cluster]
# (ClientAppActor pid=64757)
# (ClientAppActor pid=64757)
# (ClientAppActor pid=64756)
# (ClientAppActor pid=64756)
# (ClientAppActor pid=64759)
# (ClientAppActor pid=64759)
# (ClientAppActor pid=64758)
# (ClientAppActor pid=64758)
# INFO :      aggregate_evaluate: received 5 results and 0 failures
# INFO :
# INFO :      [ROUND 17]
# INFO :      configure_fit: strategy sampled 5 clients (out of 5)
# (ClientAppActor pid=64758)
# (ClientAppActor pid=64758)
# (ClientAppActor pid=64759)
# (ClientAppActor pid=64759)
# (ClientAppActor pid=64756)
# (ClientAppActor pid=64756)
# (ClientAppActor pid=64757)
# (ClientAppActor pid=64757)
# (ClientAppActor pid=64755)
# (ClientAppActor pid=64755)
# INFO :      aggregate_fit: received 5 results and 0 failures
# INFO :      fit progress: (17, 0.36459273104660045, {'test_accuracy': 0.8665}, 244.6728071672842)
# INFO :      configure_evaluate: strategy sampled 5 clients (out of 5)
# [Round 17] Test Loss: 0.3646, Accuracy: 0.8665
# (ClientAppActor pid=64755)
# (ClientAppActor pid=64755)
# (ClientAppActor pid=64755) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 10x across cluster]
# (ClientAppActor pid=64755)             This is a deprecated feature. It will be removed [repeated 10x across cluster]
# (ClientAppActor pid=64755)             entirely in future versions of Flower. [repeated 10x across cluster]
# (ClientAppActor pid=64757)
# (ClientAppActor pid=64757)
# (ClientAppActor pid=64756)
# (ClientAppActor pid=64756)
# (ClientAppActor pid=64759)
# (ClientAppActor pid=64759)
# (ClientAppActor pid=64758)
# (ClientAppActor pid=64758)
# INFO :      aggregate_evaluate: received 5 results and 0 failures
# INFO :
# INFO :      [ROUND 18]
# INFO :      configure_fit: strategy sampled 5 clients (out of 5)
# (ClientAppActor pid=64758)
# (ClientAppActor pid=64758)
# (ClientAppActor pid=64756)
# (ClientAppActor pid=64756)
# (ClientAppActor pid=64759)
# (ClientAppActor pid=64759)
# (ClientAppActor pid=64755)
# (ClientAppActor pid=64755)
# (ClientAppActor pid=64757)
# (ClientAppActor pid=64757)
# INFO :      aggregate_fit: received 5 results and 0 failures
# INFO :      fit progress: (18, 0.36093276805771046, {'test_accuracy': 0.8701}, 258.1777865830809)
# INFO :      configure_evaluate: strategy sampled 5 clients (out of 5)
# [Round 18] Test Loss: 0.3609, Accuracy: 0.8701
# (ClientAppActor pid=64755)
# (ClientAppActor pid=64755)
# (ClientAppActor pid=64755) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 10x across cluster]
# (ClientAppActor pid=64755)             This is a deprecated feature. It will be removed [repeated 10x across cluster]
# (ClientAppActor pid=64755)             entirely in future versions of Flower. [repeated 10x across cluster]
# (ClientAppActor pid=64757)
# (ClientAppActor pid=64757)
# (ClientAppActor pid=64756)
# (ClientAppActor pid=64756)
# (ClientAppActor pid=64759)
# (ClientAppActor pid=64759)
# (ClientAppActor pid=64758)
# (ClientAppActor pid=64758)
# INFO :      aggregate_evaluate: received 5 results and 0 failures
# INFO :
# INFO :      [ROUND 19]
# INFO :      configure_fit: strategy sampled 5 clients (out of 5)
# (ClientAppActor pid=64758)
# (ClientAppActor pid=64758)
# (ClientAppActor pid=64756)
# (ClientAppActor pid=64756)
# (ClientAppActor pid=64757)
# (ClientAppActor pid=64757)
# (ClientAppActor pid=64759)
# (ClientAppActor pid=64759)
# (ClientAppActor pid=64755)
# (ClientAppActor pid=64755)
# INFO :      aggregate_fit: received 5 results and 0 failures
# INFO :      fit progress: (19, 0.3529713240127784, {'test_accuracy': 0.8726}, 272.1216479581781)
# INFO :      configure_evaluate: strategy sampled 5 clients (out of 5)
# [Round 19] Test Loss: 0.3530, Accuracy: 0.8726
# (ClientAppActor pid=64755)
# (ClientAppActor pid=64755)
# (ClientAppActor pid=64755) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 10x across cluster]
# (ClientAppActor pid=64755)             This is a deprecated feature. It will be removed [repeated 10x across cluster]
# (ClientAppActor pid=64755)             entirely in future versions of Flower. [repeated 10x across cluster]
# (ClientAppActor pid=64757)
# (ClientAppActor pid=64757)
# (ClientAppActor pid=64759)
# (ClientAppActor pid=64759)
# (ClientAppActor pid=64758)
# (ClientAppActor pid=64758)
# (ClientAppActor pid=64756)
# (ClientAppActor pid=64756)
# INFO :      aggregate_evaluate: received 5 results and 0 failures
# INFO :
# INFO :      [ROUND 20]
# INFO :      configure_fit: strategy sampled 5 clients (out of 5)
# (ClientAppActor pid=64758)
# (ClientAppActor pid=64758)
# (ClientAppActor pid=64756)
# (ClientAppActor pid=64756)
# (ClientAppActor pid=64755)
# (ClientAppActor pid=64755)
# (ClientAppActor pid=64757)
# (ClientAppActor pid=64757)
# (ClientAppActor pid=64759)
# (ClientAppActor pid=64759)
# INFO :      aggregate_fit: received 5 results and 0 failures
# INFO :      fit progress: (20, 0.3501398262029258, {'test_accuracy': 0.8725}, 287.9608835000545)
# INFO :      configure_evaluate: strategy sampled 5 clients (out of 5)
# [Round 20] Test Loss: 0.3501, Accuracy: 0.8725
# (ClientAppActor pid=64759)
# (ClientAppActor pid=64759)
# (ClientAppActor pid=64759) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 10x across cluster]
# (ClientAppActor pid=64759)             This is a deprecated feature. It will be removed [repeated 10x across cluster]
# (ClientAppActor pid=64759)             entirely in future versions of Flower. [repeated 10x across cluster]
# (ClientAppActor pid=64755)
# (ClientAppActor pid=64755)
# (ClientAppActor pid=64757)
# (ClientAppActor pid=64757)
# (ClientAppActor pid=64756)
# (ClientAppActor pid=64756)
# (ClientAppActor pid=64758)
# (ClientAppActor pid=64758)
# INFO :      aggregate_evaluate: received 5 results and 0 failures
# INFO :
# INFO :      [ROUND 21]
# INFO :      configure_fit: strategy sampled 5 clients (out of 5)
# (ClientAppActor pid=64758)
# (ClientAppActor pid=64758)
# (ClientAppActor pid=64756)
# (ClientAppActor pid=64756)
# (ClientAppActor pid=64755)
# (ClientAppActor pid=64755)
# (ClientAppActor pid=64757)
# (ClientAppActor pid=64757)
# (ClientAppActor pid=64759)
# (ClientAppActor pid=64759)
# INFO :      aggregate_fit: received 5 results and 0 failures
# INFO :      fit progress: (21, 0.3458228612455507, {'test_accuracy': 0.8762}, 301.8262600423768)
# INFO :      configure_evaluate: strategy sampled 5 clients (out of 5)
# [Round 21] Test Loss: 0.3458, Accuracy: 0.8762
# (ClientAppActor pid=64757)
# (ClientAppActor pid=64757)
# (ClientAppActor pid=64757) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 10x across cluster]
# (ClientAppActor pid=64757)             This is a deprecated feature. It will be removed [repeated 10x across cluster]
# (ClientAppActor pid=64757)             entirely in future versions of Flower. [repeated 10x across cluster]
# (ClientAppActor pid=64755)
# (ClientAppActor pid=64755)
# (ClientAppActor pid=64759)
# (ClientAppActor pid=64759)
# (ClientAppActor pid=64756)
# (ClientAppActor pid=64756)
# (ClientAppActor pid=64758)
# (ClientAppActor pid=64758)
# INFO :      aggregate_evaluate: received 5 results and 0 failures
# INFO :
# INFO :      [ROUND 22]
# INFO :      configure_fit: strategy sampled 5 clients (out of 5)
# (ClientAppActor pid=64758)
# (ClientAppActor pid=64758)
# (ClientAppActor pid=64756)
# (ClientAppActor pid=64756)
# (ClientAppActor pid=64755)
# (ClientAppActor pid=64755)
# (ClientAppActor pid=64757)
# (ClientAppActor pid=64757)
# (ClientAppActor pid=64759)
# (ClientAppActor pid=64759)
# INFO :      aggregate_fit: received 5 results and 0 failures
# INFO :      fit progress: (22, 0.34475642518875316, {'test_accuracy': 0.8742}, 316.65818725014105)
# INFO :      configure_evaluate: strategy sampled 5 clients (out of 5)
# [Round 22] Test Loss: 0.3448, Accuracy: 0.8742
# (ClientAppActor pid=64759)
# (ClientAppActor pid=64759)
# (ClientAppActor pid=64759) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 10x across cluster]
# (ClientAppActor pid=64759)             This is a deprecated feature. It will be removed [repeated 10x across cluster]
# (ClientAppActor pid=64759)             entirely in future versions of Flower. [repeated 10x across cluster]
# (ClientAppActor pid=64757)
# (ClientAppActor pid=64757)
# (ClientAppActor pid=64755)
# (ClientAppActor pid=64755)
# (ClientAppActor pid=64756)
# (ClientAppActor pid=64756)
# (ClientAppActor pid=64758)
# (ClientAppActor pid=64758)
# INFO :      aggregate_evaluate: received 5 results and 0 failures
# INFO :
# INFO :      [ROUND 23]
# INFO :      configure_fit: strategy sampled 5 clients (out of 5)
# (ClientAppActor pid=64758)
# (ClientAppActor pid=64758)
# (ClientAppActor pid=64756)
# (ClientAppActor pid=64756)
# (ClientAppActor pid=64755)
# (ClientAppActor pid=64755)
# (ClientAppActor pid=64757)
# (ClientAppActor pid=64757)
# (ClientAppActor pid=64759)
# (ClientAppActor pid=64759)
# INFO :      aggregate_fit: received 5 results and 0 failures
# INFO :      fit progress: (23, 0.33836987638435423, {'test_accuracy': 0.8793}, 333.70018275035545)
# INFO :      configure_evaluate: strategy sampled 5 clients (out of 5)
# [Round 23] Test Loss: 0.3384, Accuracy: 0.8793
# (ClientAppActor pid=64759)
# (ClientAppActor pid=64759)
# (ClientAppActor pid=64759) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 10x across cluster]
# (ClientAppActor pid=64759)             This is a deprecated feature. It will be removed [repeated 10x across cluster]
# (ClientAppActor pid=64759)             entirely in future versions of Flower. [repeated 10x across cluster]
# (ClientAppActor pid=64757)
# (ClientAppActor pid=64757)
# (ClientAppActor pid=64755)
# (ClientAppActor pid=64755)
# (ClientAppActor pid=64756)
# (ClientAppActor pid=64756)
# (ClientAppActor pid=64758)
# (ClientAppActor pid=64758)
# INFO :      aggregate_evaluate: received 5 results and 0 failures
# INFO :
# INFO :      [ROUND 24]
# INFO :      configure_fit: strategy sampled 5 clients (out of 5)
# (ClientAppActor pid=64758)
# (ClientAppActor pid=64758)
# (ClientAppActor pid=64756)
# (ClientAppActor pid=64756)
# (ClientAppActor pid=64755)
# (ClientAppActor pid=64755)
# (ClientAppActor pid=64757)
# (ClientAppActor pid=64757)
# (ClientAppActor pid=64759)
# (ClientAppActor pid=64759)
# INFO :      aggregate_fit: received 5 results and 0 failures
# INFO :      fit progress: (24, 0.33406690817576246, {'test_accuracy': 0.8789}, 347.3464629170485)
# INFO :      configure_evaluate: strategy sampled 5 clients (out of 5)
# [Round 24] Test Loss: 0.3341, Accuracy: 0.8789
# (ClientAppActor pid=64759)
# (ClientAppActor pid=64759)
# (ClientAppActor pid=64759) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 10x across cluster]
# (ClientAppActor pid=64759)             This is a deprecated feature. It will be removed [repeated 10x across cluster]
# (ClientAppActor pid=64759)             entirely in future versions of Flower. [repeated 10x across cluster]
# (ClientAppActor pid=64755)
# (ClientAppActor pid=64755)
# (ClientAppActor pid=64757)
# (ClientAppActor pid=64757)
# (ClientAppActor pid=64756)
# (ClientAppActor pid=64756)
# (ClientAppActor pid=64758)
# (ClientAppActor pid=64758)
# INFO :      aggregate_evaluate: received 5 results and 0 failures
# INFO :
# INFO :      [ROUND 25]
# INFO :      configure_fit: strategy sampled 5 clients (out of 5)
# (ClientAppActor pid=64758)
# (ClientAppActor pid=64758)
# (ClientAppActor pid=64756)
# (ClientAppActor pid=64756)
# (ClientAppActor pid=64755)
# (ClientAppActor pid=64755)
# (ClientAppActor pid=64757)
# (ClientAppActor pid=64757)
# (ClientAppActor pid=64759)
# (ClientAppActor pid=64759)
# INFO :      aggregate_fit: received 5 results and 0 failures
# INFO :      fit progress: (25, 0.33153331730836116, {'test_accuracy': 0.8808}, 360.0984443752095)
# INFO :      configure_evaluate: strategy sampled 5 clients (out of 5)
# [Round 25] Test Loss: 0.3315, Accuracy: 0.8808
# (ClientAppActor pid=64757)
# (ClientAppActor pid=64757)
# (ClientAppActor pid=64757) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 10x across cluster]
# (ClientAppActor pid=64757)             This is a deprecated feature. It will be removed [repeated 10x across cluster]
# (ClientAppActor pid=64757)             entirely in future versions of Flower. [repeated 10x across cluster]
# (ClientAppActor pid=64756)
# (ClientAppActor pid=64756)
# (ClientAppActor pid=64755)
# (ClientAppActor pid=64755)
# (ClientAppActor pid=64759)
# (ClientAppActor pid=64759)
# (ClientAppActor pid=64758)
# (ClientAppActor pid=64758)
# INFO :      aggregate_evaluate: received 5 results and 0 failures
# INFO :
# INFO :      [ROUND 26]
# INFO :      configure_fit: strategy sampled 5 clients (out of 5)
# (ClientAppActor pid=64758)
# (ClientAppActor pid=64758)
# (ClientAppActor pid=64756)
# (ClientAppActor pid=64756)
# (ClientAppActor pid=64755)
# (ClientAppActor pid=64755)
# (ClientAppActor pid=64759)
# (ClientAppActor pid=64759)
# (ClientAppActor pid=64757)
# (ClientAppActor pid=64757)
# INFO :      aggregate_fit: received 5 results and 0 failures
# INFO :      fit progress: (26, 0.32997950360464595, {'test_accuracy': 0.8795}, 372.4907046253793)
# INFO :      configure_evaluate: strategy sampled 5 clients (out of 5)
# [Round 26] Test Loss: 0.3300, Accuracy: 0.8795
# (ClientAppActor pid=64757)
# (ClientAppActor pid=64757)
# (ClientAppActor pid=64757) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 10x across cluster]
# (ClientAppActor pid=64757)             This is a deprecated feature. It will be removed [repeated 10x across cluster]
# (ClientAppActor pid=64757)             entirely in future versions of Flower. [repeated 10x across cluster]
# (ClientAppActor pid=64759)
# (ClientAppActor pid=64759)
# (ClientAppActor pid=64756)
# (ClientAppActor pid=64756)
# (ClientAppActor pid=64755)
# (ClientAppActor pid=64755)
# (ClientAppActor pid=64758)
# (ClientAppActor pid=64758)
# INFO :      aggregate_evaluate: received 5 results and 0 failures
# INFO :
# INFO :      [ROUND 27]
# INFO :      configure_fit: strategy sampled 5 clients (out of 5)
# (ClientAppActor pid=64758)
# (ClientAppActor pid=64758)
# (ClientAppActor pid=64756)
# (ClientAppActor pid=64756)
# (ClientAppActor pid=64759)
# (ClientAppActor pid=64759)
# (ClientAppActor pid=64755)
# (ClientAppActor pid=64755)
# (ClientAppActor pid=64757)
# (ClientAppActor pid=64757)
# INFO :      aggregate_fit: received 5 results and 0 failures
# INFO :      fit progress: (27, 0.3238117027515992, {'test_accuracy': 0.8833}, 384.9308561673388)
# INFO :      configure_evaluate: strategy sampled 5 clients (out of 5)
# [Round 27] Test Loss: 0.3238, Accuracy: 0.8833
# (ClientAppActor pid=64755)
# (ClientAppActor pid=64755)
# (ClientAppActor pid=64755) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 10x across cluster]
# (ClientAppActor pid=64755)             This is a deprecated feature. It will be removed [repeated 10x across cluster]
# (ClientAppActor pid=64755)             entirely in future versions of Flower. [repeated 10x across cluster]
# (ClientAppActor pid=64757)
# (ClientAppActor pid=64757)
# (ClientAppActor pid=64759)
# (ClientAppActor pid=64759)
# (ClientAppActor pid=64758)
# (ClientAppActor pid=64758)
# (ClientAppActor pid=64756)
# (ClientAppActor pid=64756)
# INFO :      aggregate_evaluate: received 5 results and 0 failures
# INFO :
# INFO :      [ROUND 28]
# INFO :      configure_fit: strategy sampled 5 clients (out of 5)
# (ClientAppActor pid=64758)
# (ClientAppActor pid=64758)
# (ClientAppActor pid=64756)
# (ClientAppActor pid=64756)
# (ClientAppActor pid=64759)
# (ClientAppActor pid=64759)
# (ClientAppActor pid=64757)
# (ClientAppActor pid=64757)
# (ClientAppActor pid=64755)
# (ClientAppActor pid=64755)
# INFO :      aggregate_fit: received 5 results and 0 failures
# INFO :      fit progress: (28, 0.321798798410942, {'test_accuracy': 0.8819}, 398.59001041715965)
# INFO :      configure_evaluate: strategy sampled 5 clients (out of 5)
# [Round 28] Test Loss: 0.3218, Accuracy: 0.8819
# (ClientAppActor pid=64755)
# (ClientAppActor pid=64755)
# (ClientAppActor pid=64755) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 10x across cluster]
# ...
# (ClientAppActor pid=64759)             This is a deprecated feature. It will be removed [repeated 10x across cluster]
# (ClientAppActor pid=64759)             entirely in future versions of Flower. [repeated 10x across cluster]
# (ClientAppActor pid=64756)
# (ClientAppActor pid=64756)
# (ClientAppActor pid=64757)
# (ClientAppActor pid=64757)
# (ClientAppActor pid=64758)
# (ClientAppActor pid=64758)
# (ClientAppActor pid=64755)
# (ClientAppActor pid=64755)
# INFO :      aggregate_evaluate: received 5 results and 0 failures
# INFO :
# INFO :      [ROUND 100]
# INFO :      configure_fit: strategy sampled 5 clients (out of 5)
# (ClientAppActor pid=64758)
# (ClientAppActor pid=64758)
# (ClientAppActor pid=64755)
# (ClientAppActor pid=64755)
# (ClientAppActor pid=64756)
# (ClientAppActor pid=64756)
# (ClientAppActor pid=64757)
# (ClientAppActor pid=64757)
# (ClientAppActor pid=64759)
# (ClientAppActor pid=64759)
# INFO :      aggregate_fit: received 5 results and 0 failures
# INFO :      fit progress: (100, 0.24809460885846576, {'test_accuracy': 0.9103}, 1365.3081274582073)
# INFO :      configure_evaluate: strategy sampled 5 clients (out of 5)
# [Round 100] Test Loss: 0.2481, Accuracy: 0.9103
# (ClientAppActor pid=64759)
# (ClientAppActor pid=64759)
# (ClientAppActor pid=64759) WARNING :   DEPRECATED FEATURE: `client_fn` now expects a signature `def client_fn(context: Context)`.The provided `client_fn` has signature: {'cid': <Parameter "cid: str">}. You can import the `Context` like this: `from flwr.common import Context` [repeated 10x across cluster]
# (ClientAppActor pid=64759)             This is a deprecated feature. It will be removed [repeated 10x across cluster]
# (ClientAppActor pid=64759)             entirely in future versions of Flower. [repeated 10x across cluster]
# (ClientAppActor pid=
# INFO :      	                   (10, 0.8503),
# INFO :      	                   (11, 0.8516),
# INFO :      	                   (12, 0.8575),
# INFO :      	                   (13, 0.859),
# INFO :      	                   (14, 0.8583),
# INFO :      	                   (15, 0.8639),
# INFO :      	                   (16, 0.8655),
# INFO :      	                   (17, 0.8665),
# INFO :      	                   (18, 0.8701),
# INFO :      	                   (19, 0.8726),
# INFO :      	                   (20, 0.8725),
# INFO :      	                   (21, 0.8762),
# INFO :      	                   (22, 0.8742),
# INFO :      	                   (23, 0.8793),
# INFO :      	                   (24, 0.8789),
# INFO :      	                   (25, 0.8808),
# INFO :      	                   (26, 0.8795),
# INFO :      	                   (27, 0.8833),
# INFO :      	                   (28, 0.8819),
# INFO :      	                   (29, 0.8819),
# INFO :      	                   (30, 0.8837),
# INFO :      	                   (31, 0.8878),
# INFO :      	                   (32, 0.8868),
# INFO :      	                   (33, 0.885),
# INFO :      	                   (34, 0.8875),
# INFO :      	                   (35, 0.8888),
# INFO :      	                   (36, 0.8887),
# INFO :      	                   (37, 0.8879),
# INFO :      	                   (38, 0.8908),
# INFO :      	                   (39, 0.8926),
# INFO :      	                   (40, 0.8918),
# INFO :      	                   (41, 0.8935),
# INFO :      	                   (42, 0.8934),
# INFO :      	                   (43, 0.8945),
# INFO :      	                   (44, 0.8951),
# INFO :      	                   (45, 0.8972),
# INFO :      	                   (46, 0.8933),
# INFO :      	                   (47, 0.8954),
# INFO :      	                   (48, 0.8964),
# INFO :      	                   (49, 0.8973),
# INFO :      	                   (50, 0.8985),
# INFO :      	                   (51, 0.8977),
# INFO :      	                   (52, 0.8994),
# INFO :      	                   (53, 0.9005),
# INFO :      	                   (54, 0.9004),
# INFO :      	                   (55, 0.9003),
# INFO :      	                   (56, 0.8997),
# INFO :      	                   (57, 0.901),
# INFO :      	                   (58, 0.9011),
# INFO :      	                   (59, 0.9006),
# INFO :      	                   (60, 0.898),
# INFO :      	                   (61, 0.9034),
# INFO :      	                   (62, 0.904),
# INFO :      	                   (63, 0.9049),
# INFO :      	                   (64, 0.9052),
# INFO :      	                   (65, 0.9037),
# INFO :      	                   (66, 0.905),
# INFO :      	                   (67, 0.9034),
# INFO :      	                   (68, 0.9044),
# INFO :      	                   (69, 0.9049),
# INFO :      	                   (70, 0.9065),
# INFO :      	                   (71, 0.9054),
# INFO :      	                   (72, 0.9085),
# INFO :      	                   (73, 0.9073),
# INFO :      	                   (74, 0.9069),
# INFO :      	                   (75, 0.9074),
# INFO :      	                   (76, 0.9062),
# INFO :      	                   (77, 0.9086),
# INFO :      	                   (78, 0.9097),
# INFO :      	                   (79, 0.9068),
# INFO :      	                   (80, 0.9093),
# INFO :      	                   (81, 0.9089),
# INFO :      	                   (82, 0.9091),
# INFO :      	                   (83, 0.9079),
# INFO :      	                   (84, 0.9099),
# INFO :      	                   (85, 0.9099),
# INFO :      	                   (86, 0.9083),
# INFO :      	                   (87, 0.9077),
# INFO :      	                   (88, 0.912),
# INFO :      	                   (89, 0.9089),
# INFO :      	                   (90, 0.91),
# INFO :      	                   (91, 0.9111),
# INFO :      	                   (92, 0.9096),
# INFO :      	                   (93, 0.9102),
# INFO :      	                   (94, 0.9072),
# INFO :      	                   (95, 0.9107),
# INFO :      	                   (96, 0.9123),
# INFO :      	                   (97, 0.9112),
# INFO :      	                   (98, 0.9122),
# INFO :      	                   (99, 0.9111),
# INFO :      	                   (100, 0.9103)]}
# INFO :

# %% [markdown]
# PLOTTING ACCURACY AND LOSS SEPARATELY

# %%
import numpy as np
import matplotlib.pyplot as plt

# Load accuracy arrays
fedavg_acc       = np.load("fashionmnist_fedavg_test_accuracies.npy")[:100]
fedadam_acc      = np.load("fashionmnist_test_accuracies.npy")[:100]
fedadagrad_acc   = np.load("fashionmnist_fedadagrad_test_accuracies.npy")[:100]
fedyogi_acc      = np.load("fashionmnist_fedyogi_accuracies.npy")[:100]
scaffold_acc     = np.load("scaffold_fashionmnist_test_accuracies.npy")[:100]

# Load loss arrays
fedavg_loss      = np.load("fashionmnist_fedavg_test_losses.npy")[:100]
fedadam_loss     = np.load("fashionmnist_test_losses.npy")[:100]
fedadagrad_loss  = np.load("fashionmnist_fedadagrad_test_losses.npy")[:100]
fedyogi_loss     = np.load("fashionmnist_fedyogi_losses.npy")[:100]
scaffold_loss    = np.load("scaffold_fashionmnist_test_losses.npy")[:100]

# Rounds
rounds = list(range(1, 101))

# ----- Accuracy Plot -----
plt.figure(figsize=(12, 6))
plt.plot(rounds, fedavg_acc, label="FedAvg", marker='o')
plt.plot(rounds, fedadam_acc, label="FedAdam", marker='s')
plt.plot(rounds, fedadagrad_acc, label="FedAdagrad", marker='^')
plt.plot(rounds, fedyogi_acc, label="FedYogi", marker='x')
plt.plot(rounds, scaffold_acc, label="SCAFFOLD", marker='d')
plt.xlabel("Round")
plt.ylabel("Test Accuracy")
plt.title("FashionMNIST - Test Accuracy Comparison (All Strategies)")
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.savefig("fashionmnist_comparison_test_accuracy_with_scaffold.png")
plt.show()

# ----- Loss Plot -----
plt.figure(figsize=(12, 6))
plt.plot(rounds, fedavg_loss, label="FedAvg", marker='o')
plt.plot(rounds, fedadam_loss, label="FedAdam", marker='s')
plt.plot(rounds, fedadagrad_loss, label="FedAdagrad", marker='^')
plt.plot(rounds, fedyogi_loss, label="FedYogi", marker='x')
plt.plot(rounds, scaffold_loss, label="SCAFFOLD", marker='d')
plt.xlabel("Round")
plt.ylabel("Test Loss")
plt.title("FashionMNIST - Test Loss Comparison (All Strategies)")
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.savefig("fashionmnist_comparison_test_loss_with_scaffold.png")
plt.show()

# %% [markdown]
# STRATEGY COMPARISON CHART

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# Load accuracy arrays 
fedavg_acc       = np.load("fashionmnist_fedavg_test_accuracies.npy")[:100]
fedadam_acc      = np.load("fashionmnist_test_accuracies.npy")[:100]
fedadagrad_acc   = np.load("fashionmnist_fedadagrad_test_accuracies.npy")[:100]
fedyogi_acc      = np.load("fashionmnist_fedyogi_accuracies.npy")[:100]
scaffold_acc     = np.load("scaffold_fashionmnist_test_accuracies.npy")[:100]

# Load loss arrays 
fedavg_loss      = np.load("fashionmnist_fedavg_test_losses.npy")[:100]
fedadam_loss     = np.load("fashionmnist_test_losses.npy")[:100]
fedadagrad_loss  = np.load("fashionmnist_fedadagrad_test_losses.npy")[:100]
fedyogi_loss     = np.load("fashionmnist_fedyogi_losses.npy")[:100]
scaffold_loss    = np.load("scaffold_fashionmnist_test_losses.npy")[:100]

# Rounds
rounds = np.arange(1, 101)

# Create subplots
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 6))

# Accuracy subplot
ax1.plot(rounds, fedavg_acc, label="FedAvg")
ax1.plot(rounds, fedadam_acc, label="FedAdam")
ax1.plot(rounds, fedadagrad_acc, label="FedAdagrad")
ax1.plot(rounds, fedyogi_acc, label="FedYogi")
ax1.plot(rounds, scaffold_acc, label="SCAFFOLD")
ax1.set_title("FashionMNIST - Test Accuracy per Round")
ax1.set_xlabel("Round")
ax1.set_ylabel("Accuracy")
ax1.grid(True)
ax1.legend()

# Loss subplot
ax2.plot(rounds, fedavg_loss, label="FedAvg")
ax2.plot(rounds, fedadam_loss, label="FedAdam")
ax2.plot(rounds, fedadagrad_loss, label="FedAdagrad")
ax2.plot(rounds, fedyogi_loss, label="FedYogi")
ax2.plot(rounds, scaffold_loss, label="SCAFFOLD")
ax2.set_title("FashionMNIST - Test Loss per Round")
ax2.set_xlabel("Round")
ax2.set_ylabel("Loss")
ax2.grid(True)
ax2.legend()

# Super title and save
plt.suptitle("FashionMNIST Strategy Comparison: Accuracy and Loss Over 100 Rounds")
plt.tight_layout()
plt.savefig("fashionmnist_subplots_accuracy_loss_with_scaffold.png")
plt.show()

# %% [markdown]
# DATA IN TABLE AND LOADED AS CSV

# %%
import numpy as np
import pandas as pd

# Load accuracy arrays 
fedavg_acc       = np.load("fashionmnist_fedavg_test_accuracies.npy")[:100]
fedadam_acc      = np.load("fashionmnist_test_accuracies.npy")[:100]
fedadagrad_acc   = np.load("fashionmnist_fedadagrad_test_accuracies.npy")[:100]
fedyogi_acc      = np.load("fashionmnist_fedyogi_accuracies.npy")[:100]
scaffold_acc     = np.load("scaffold_fashionmnist_test_accuracies.npy")[:100]

# Load loss arrays 
fedavg_loss      = np.load("fashionmnist_fedavg_test_losses.npy")[:100]
fedadam_loss     = np.load("fashionmnist_test_losses.npy")[:100]
fedadagrad_loss  = np.load("fashionmnist_fedadagrad_test_losses.npy")[:100]
fedyogi_loss     = np.load("fashionmnist_fedyogi_losses.npy")[:100]
scaffold_loss    = np.load("scaffold_fashionmnist_test_losses.npy")[:100]

# Rounds
rounds = list(range(1, 101))

# ----- Create and Print Accuracy Table -----
accuracy_df = pd.DataFrame({
    "Round": rounds,
    "FedAvg": fedavg_acc,
    "FedAdam": fedadam_acc,
    "FedAdagrad": fedadagrad_acc,
    "FedYogi": fedyogi_acc,
    "SCAFFOLD": scaffold_acc,
})
print("\n===== Test Accuracy Table (FashionMNIST, 100 Rounds) =====")
print(accuracy_df.to_string(index=False))

# ----- Create and Print Loss Table -----
loss_df = pd.DataFrame({
    "Round": rounds,
    "FedAvg": fedavg_loss,
    "FedAdam": fedadam_loss,
    "FedAdagrad": fedadagrad_loss,
